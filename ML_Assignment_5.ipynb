# %%
import os
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
# Load data
df = pd.read_csv('abalone.data.csv')

# %%
# Perform one-hot encoding for gender column
df = pd.get_dummies(df, columns=['Sex'])

# %%
# Standardize continuous features
continuous_columns = ['Length', 'Diameter', 'Height', 'Whole_weight', 'Shucked_weight', 'Viscera_weight', 'Shell_weight']
scaler = StandardScaler()
df[continuous_columns] = scaler.fit_transform(df[continuous_columns])

# %%
# Separate features and target
X = df.drop('Rings', axis=1).values
y = df['Rings'].values

# %%
# Split data into training and testing sets (using 80-20 split)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=49)

# %%
# Convert datasets into PyTorch tensors
X_train = X_train.astype(np.float32)
X_test = X_test.astype(np.float32)
y_train = y_train.astype(np.float32).reshape(-1, 1)
y_test = y_test.astype(np.float32).reshape(-1, 1)

X_train_tensor = torch.tensor(X_train)
X_test_tensor = torch.tensor(X_test)
y_train_tensor = torch.tensor(y_train)
y_test_tensor = torch.tensor(y_test)

# %%
# Define a class AbaloneModel

class AbaloneModel(nn.Module):
    def __init__(self):
        super(AbaloneModel, self).__init__()
        self.fc1 = nn.Linear(10, 64)
        self.fc2 = nn.Linear(64, 32)
        self.fc3 = nn.Linear(32, 1)
        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.relu(self.fc1(x))
        x = self.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# %%
model = AbaloneModel()
criterion = nn.MSELoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.01)

# %%
def train_model(model, criterion, optimizer, X_train, y_train, epochs=100):
    for epoch in range(epochs):
        model.train()
        optimizer.zero_grad()
        outputs = model(X_train_tensor)
        loss = criterion(outputs, y_train_tensor)
        loss.backward()
        optimizer.step()

train_model(model, criterion, optimizer, X_train_tensor, y_train_tensor)

# %%
def evaluate(model, X_test, y_test):
    model.eval()
    with torch.no_grad():
        outputs = model(X_test)
        mse = nn.MSELoss()
        loss = mse(outputs, y_test)
    return loss.item()

mse = evaluate(model, X_test_tensor, y_test_tensor)
print("Mean Squared Error on Test Set:", mse)
# Out:
# Mean Squared Error on Test Set: 5.463046073913574

# %%
# Define the Adagrad optimizer
optimizer_adagrad = torch.optim.Adagrad(model.parameters(), lr=0.01)

# Train the model with Adagrad optimizer
train_model(model, criterion, optimizer_adagrad, X_train_tensor, y_train_tensor)

# Evaluate the model
mse_adagrad = evaluate(model, X_test_tensor, y_test_tensor)
print("Mean Squared Error with Adagrad optimizer:", mse_adagrad)
# Out:
# Mean Squared Error with Adagrad optimizer: 5.044127464294434

# %% [markdown]
# Observations:
#
# MSE Comparison: The Mean Squared Error (MSE) obtained using Adagrad (5.097) is lower than the MSE obtained using SGD (5.482). This indicates that the model trained with Adagrad performs slightly better in terms of minimizing the loss compared to the model trained with SGD.
#
# Adaptive Learning Rates: Adagrad adapts the learning rates of each parameter based on the frequency of parameter updates during training. This adaptiveness can be beneficial for training deep neural networks, as it allows for different learning rates for different parameters. In contrast, SGD uses a fixed learning rate throughout training, which may not be optimal for all parameters.
#
# Convergence Speed: Adagrad may converge faster than SGD for certain problems, especially when the learning rates need to be adjusted dynamically during training. However, it's essential to monitor convergence behavior and avoid overfitting, as Adagrad's aggressive learning rate adaptation can lead to unstable training dynamics in some cases.
#
# Performance Trade-offs: While Adagrad may offer better performance in terms of minimizing the loss, it comes with computational overhead due to the accumulation of squared gradients in the denominator of the learning rate update formula. This can lead to slower training compared to SGD, especially for large-scale datasets and complex models.
#
# Hyperparameter Sensitivity: Both Adagrad and SGD have hyperparameters that need to be carefully tuned for optimal performance. The choice of learning rate, batch size, and other hyperparameters can significantly impact the training dynamics and final performance of the model. Experimentation and cross-validation are crucial for identifying the best hyperparameters for a given task.
#
# In summary, Adagrad generally offers better performance in terms of minimizing the loss compared to SGD, thanks to its adaptive learning rate mechanism. However, it's essential to consider the trade-offs in convergence speed, computational complexity, and hyperparameter sensitivity when choosing between different optimization algorithms for training neural networks.

# %% [markdown]
# Now, starting with Hyper-parameter analysis and tuning (Finding the combination of hyper-parameters which gives the least MSE).

# %%
# Define a class AbaloneModel_hyper for hyperparameter analysis and tuning

class AbaloneModel_hyper(nn.Module):
    def __init__(self, num_hidden_layers=1, num_hidden_nodes=64):
        super(AbaloneModel_hyper, self).__init__()
        self.input_layer = nn.Linear(10, num_hidden_nodes)
        self.hidden_layers = nn.ModuleList([nn.Linear(num_hidden_nodes, num_hidden_nodes) for _ in range(num_hidden_layers)])
        self.output_layer = nn.Linear(num_hidden_nodes, 1)
        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.relu(self.input_layer(x))
        for layer in self.hidden_layers:
            x = self.relu(layer(x))
        x = self.output_layer(x)
        return x

# %%
# Define train_model_hyper for hyperparameter analysis and tuning

def train_model_hyper(model, criterion, optimizer, X_train, y_train, batch_size, epochs=100):
    data_size = X_train.size(0)
    num_batches = (data_size + batch_size - 1) // batch_size

    for epoch in range(epochs):
        model.train()  # Set the model to training mode
        epoch_loss = 0.0
        for i in range(num_batches):
            start_idx = i * batch_size
            end_idx = min((i + 1) * batch_size, data_size)
            batch_X = X_train[start_idx:end_idx]
            batch_y = y_train[start_idx:end_idx]

            optimizer.zero_grad()  # Clear gradients
            outputs = model(batch_X)  # Forward pass
            loss = criterion(outputs, batch_y)  # Calculate loss
            loss.backward()  # Backward pass
            optimizer.step()  # Update weights
            epoch_loss += loss.item()

        # Print average loss for the epoch
        avg_loss = epoch_loss / num_batches
        print(f'Epoch [{epoch + 1}/{epochs}], Avg. Loss: {avg_loss:.4f}')

# Example usage:
model = AbaloneModel_hyper()
criterion = nn.MSELoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.01)
train_model_hyper(model, criterion, optimizer, X_train_tensor, y_train_tensor, batch_size=32, epochs=100)
# Out:
# Epoch [1/100], Avg. Loss: 12.5229
# Epoch [2/100], Avg. Loss: 5.6597
# Epoch [3/100], Avg. Loss: 5.2014
# Epoch [4/100], Avg. Loss: 5.0581
# Epoch [5/100], Avg. Loss: 4.9504
# Epoch [6/100], Avg. Loss: 4.8682
# Epoch [7/100], Avg. Loss: 4.7981
# Epoch [8/100], Avg. Loss: 4.7404
# Epoch [9/100], Avg. Loss: 4.6922
# Epoch [10/100], Avg. Loss: 4.6485
# Epoch [11/100], Avg. Loss: 4.6107
# Epoch [12/100], Avg. Loss: 4.5701
# Epoch [13/100], Avg. Loss: 4.5415
# Epoch [14/100], Avg. Loss: 4.5118
# Epoch [15/100], Avg. Loss: 4.4844
# Epoch [16/100], Avg. Loss: 4.4604
# Epoch [17/100], Avg. Loss: 4.4382
# Epoch [18/100], Avg. Loss: 4.4140
# Epoch [19/100], Avg. Loss: 4.3968
# Epoch [20/100], Avg. Loss: 4.3709
# Epoch [21/100], Avg. Loss: 4.3549
# Epoch [22/100], Avg. Loss: 4.3387
# Epoch [23/100], Avg. Loss: 4.3184
# Epoch [24/100], Avg. Loss: 4.2996
# Epoch [25/100], Avg. Loss: 4.2810
# Epoch [26/100], Avg. Loss: 4.2721
# Epoch [27/100], Avg. Loss: 4.2555
# Epoch [28/100], Avg. Loss: 4.2414
# Epoch [29/100], Avg. Loss: 4.2285
# Epoch [30/100], Avg. Loss: 4.2110
# Epoch [31/100], Avg. Loss: 4.2004
# Epoch [32/100], Avg. Loss: 4.1848
# Epoch [33/100], Avg. Loss: 4.1698
# Epoch [34/100], Avg. Loss: 4.1618
# Epoch [35/100], Avg. Loss: 4.1524
# Epoch [36/100], Avg. Loss: 4.1410
# Epoch [37/100], Avg. Loss: 4.1342
# Epoch [38/100], Avg. Loss: 4.1243
# Epoch [39/100], Avg. Loss: 4.1167
# Epoch [40/100], Avg. Loss: 4.1103
# Epoch [41/100], Avg. Loss: 4.1031
# Epoch [42/100], Avg. Loss: 4.0925
# Epoch [43/100], Avg. Loss: 4.0874
# Epoch [44/100], Avg. Loss: 4.0806
# Epoch [45/100], Avg. Loss: 4.0746
# Epoch [46/100], Avg. Loss: 4.0669
# Epoch [47/100], Avg. Loss: 4.0596
# Epoch [48/100], Avg. Loss: 4.0542
# Epoch [49/100], Avg. Loss: 4.0453
# Epoch [50/100], Avg. Loss: 4.0425
# Epoch [51/100], Avg. Loss: 4.0384
# Epoch [52/100], Avg. Loss: 4.0307
# Epoch [53/100], Avg. Loss: 4.0254
# Epoch [54/100], Avg. Loss: 4.0187
# Epoch [55/100], Avg. Loss: 4.0130
# Epoch [56/100], Avg. Loss: 4.0136
# Epoch [57/100], Avg. Loss: 4.0078
# Epoch [58/100], Avg. Loss: 4.0041
# Epoch [59/100], Avg. Loss: 3.9959
# Epoch [60/100], Avg. Loss: 3.9930
# Epoch [61/100], Avg. Loss: 3.9910
# Epoch [62/100], Avg. Loss: 3.9845
# Epoch [63/100], Avg. Loss: 3.9807
# Epoch [64/100], Avg. Loss: 3.9762
# Epoch [65/100], Avg. Loss: 3.9789
# Epoch [66/100], Avg. Loss: 3.9728
# Epoch [67/100], Avg. Loss: 3.9745
# Epoch [68/100], Avg. Loss: 3.9657
# Epoch [69/100], Avg. Loss: 3.9867
# Epoch [70/100], Avg. Loss: 3.9782
# Epoch [71/100], Avg. Loss: 4.0362
# Epoch [72/100], Avg. Loss: 4.0013
# Epoch [73/100], Avg. Loss: 4.0079
# Epoch [74/100], Avg. Loss: 3.9625
# Epoch [75/100], Avg. Loss: 3.9578
# Epoch [76/100], Avg. Loss: 3.9383
# Epoch [77/100], Avg. Loss: 3.9356
# Epoch [78/100], Avg. Loss: 3.9302
# Epoch [79/100], Avg. Loss: 3.9228
# Epoch [80/100], Avg. Loss: 3.9229
# Epoch [81/100], Avg. Loss: 3.9191
# Epoch [82/100], Avg. Loss: 3.9166
# Epoch [83/100], Avg. Loss: 3.9091
# Epoch [84/100], Avg. Loss: 3.9051
# Epoch [85/100], Avg. Loss: 3.9038
# Epoch [86/100], Avg. Loss: 3.9005
# Epoch [87/100], Avg. Loss: 3.8966
# Epoch [88/100], Avg. Loss: 3.8933
# Epoch [89/100], Avg. Loss: 3.8903
# Epoch [90/100], Avg. Loss: 3.8831
# Epoch [91/100], Avg. Loss: 3.8843
# Epoch [92/100], Avg. Loss: 3.8766
# Epoch [93/100], Avg. Loss: 3.8862
# Epoch [94/100], Avg. Loss: 3.8858
# Epoch [95/100], Avg. Loss: 3.9426
# Epoch [96/100], Avg. Loss: 3.9622
# Epoch [97/100], Avg. Loss: 4.0273
# Epoch [98/100], Avg. Loss: 3.8801
# Epoch [99/100], Avg. Loss: 3.8664
# Epoch [100/100], Avg. Loss: 3.8553

# %%
# Ranges of the values of hyperparameters we want to analyse
learning_rates = [0.001, 0.01, 0.1]
batch_sizes = [16, 32, 64]
hidden_nodes = [32, 64, 128]
hidden_layers = [1, 2, 3, 4]

results = []

for lr in learning_rates:
    for batch_size in batch_sizes:
        for nodes in hidden_nodes:
            for layers in hidden_layers:
                # Define model with current hyperparameters
                model = AbaloneModel_hyper(num_hidden_layers=layers, num_hidden_nodes=nodes)
                criterion = nn.MSELoss()
                optimizer = torch.optim.SGD(model.parameters(), lr=lr)

                # Train the model
                train_model_hyper(model, criterion, optimizer, X_train_tensor, y_train_tensor, batch_size=batch_size)

                # Evaluate the model
                mse = evaluate(model, X_test_tensor, y_test_tensor)

                # Store results
                results.append({'Learning Rate': lr, 'Batch Size': batch_size,
                                'Hidden Nodes': nodes, 'Hidden Layers': layers, 'MSE': mse})

# Convert results to DataFrame for tabulation
results_df = pd.DataFrame(results)
# Out:
# Epoch [1/100], Avg. Loss: 29.0676
# Epoch [2/100], Avg. Loss: 5.7776
# Epoch [3/100], Avg. Loss: 5.0787
# Epoch [4/100], Avg. Loss: 4.8445
# Epoch [5/100], Avg. Loss: 4.7333
# Epoch [6/100], Avg. Loss: 4.6665
# Epoch [7/100], Avg. Loss: 4.6077
# Epoch [8/100], Avg. Loss: 4.5710
# Epoch [9/100], Avg. Loss: 4.5345
# Epoch [10/100], Avg. Loss: 4.5065
# Epoch [11/100], Avg. Loss: 4.4810
# Epoch [12/100], Avg. Loss: 4.4579
# Epoch [13/100], Avg. Loss: 4.4363
# Epoch [14/100], Avg. Loss: 4.4171
# Epoch [15/100], Avg. Loss: 4.3976
# Epoch [16/100], Avg. Loss: 4.3810
# Epoch [17/100], Avg. Loss: 4.3642
# Epoch [18/100], Avg. Loss: 4.3494
# Epoch [19/100], Avg. Loss: 4.3355
# Epoch [20/100], Avg. Loss: 4.3217
# Epoch [21/100], Avg. Loss: 4.3089
# Epoch [22/100], Avg. Loss: 4.2961
# Epoch [23/100], Avg. Loss: 4.2845
# Epoch [24/100], Avg. Loss: 4.2729
# Epoch [25/100], Avg. Loss: 4.2624
# Epoch [26/100], Avg. Loss: 4.2519
# Epoch [27/100], Avg. Loss: 4.2420
# Epoch [28/100], Avg. Loss: 4.2309
# Epoch [29/100], Avg. Loss: 4.2226
# Epoch [30/100], Avg. Loss: 4.2134
# Epoch [31/100], Avg. Loss: 4.2053
# Epoch [32/100], Avg. Loss: 4.1972
# Epoch [33/100], Avg. Loss: 4.1895
# Epoch [34/100], Avg. Loss: 4.1826
# Epoch [35/100], Avg. Loss: 4.1762
# Epoch [36/100], Avg. Loss: 4.1686
# Epoch [37/100], Avg. Loss: 4.1618
# Epoch [38/100], Avg. Loss: 4.1554
# Epoch [39/100], Avg. Loss: 4.1497
# Epoch [40/100], Avg. Loss: 4.1440
# Epoch [41/100], Avg. Loss: 4.1388
# Epoch [42/100], Avg. Loss: 4.1338
# Epoch [43/100], Avg. Loss: 4.1285
# Epoch [44/100], Avg. Loss: 4.1241
# Epoch [45/100], Avg. Loss: 4.1195
# Epoch [46/100], Avg. Loss: 4.1151
# Epoch [47/100], Avg. Loss: 4.1109
# Epoch [48/100], Avg. Loss: 4.1066
# Epoch [49/100], Avg. Loss: 4.1023
# Epoch [50/100], Avg. Loss: 4.0986
# Epoch [51/100], Avg. Loss: 4.0946
# Epoch [52/100], Avg. Loss: 4.0910
# Epoch [53/100], Avg. Loss: 4.0881
# Epoch [54/100], Avg. Loss: 4.0847
# Epoch [55/100], Avg. Loss: 4.0816
# Epoch [56/100], Avg. Loss: 4.0797
# Epoch [57/100], Avg. Loss: 4.0756
# Epoch [58/100], Avg. Loss: 4.0725
# Epoch [59/100], Avg. Loss: 4.0695
# Epoch [60/100], Avg. Loss: 4.0667
# Epoch [61/100], Avg. Loss: 4.0636
# Epoch [62/100], Avg. Loss: 4.0608
# Epoch [63/100], Avg. Loss: 4.0575
# Epoch [64/100], Avg. Loss: 4.0549
# Epoch [65/100], Avg. Loss: 4.0520
# Epoch [66/100], Avg. Loss: 4.0499
# Epoch [67/100], Avg. Loss: 4.0486
# Epoch [68/100], Avg. Loss: 4.0459
# Epoch [69/100], Avg. Loss: 4.0444
# Epoch [70/100], Avg. Loss: 4.0413
# Epoch [71/100], Avg. Loss: 4.0393
# Epoch [72/100], Avg. Loss: 4.0366
# Epoch [73/100], Avg. Loss: 4.0348
# Epoch [74/100], Avg. Loss: 4.0327
# Epoch [75/100], Avg. Loss: 4.0314
# Epoch [76/100], Avg. Loss: 4.0292
# Epoch [77/100], Avg. Loss: 4.0266
# Epoch [78/100], Avg. Loss: 4.0245
# Epoch [79/100], Avg. Loss: 4.0226
# Epoch [80/100], Avg. Loss: 4.0200
# Epoch [81/100], Avg. Loss: 4.0182
# Epoch [82/100], Avg. Loss: 4.0173
# Epoch [83/100], Avg. Loss: 4.0155
# Epoch [84/100], Avg. Loss: 4.0141
# Epoch [85/100], Avg. Loss: 4.0125
# Epoch [86/100], Avg. Loss: 4.0108
# Epoch [87/100], Avg. Loss: 4.0087
# Epoch [88/100], Avg. Loss: 4.0069
# Epoch [89/100], Avg. Loss: 4.0057
# Epoch [90/100], Avg. Loss: 4.0043
# Epoch [91/100], Avg. Loss: 4.0022
# Epoch [92/100], Avg. Loss: 4.0004
# Epoch [93/100], Avg. Loss: 3.9990
# Epoch [94/100], Avg. Loss: 3.9974
# Epoch [95/100], Avg. Loss: 3.9961
# Epoch [96/100], Avg. Loss: 3.9946
# Epoch [97/100], Avg. Loss: 3.9932
# Epoch [98/100], Avg. Loss: 3.9921
# Epoch [99/100], Avg. Loss: 3.9909
# Epoch [100/100], Avg. Loss: 3.9896
# Epoch [1/100], Avg. Loss: 38.5426
# Epoch [2/100], Avg. Loss: 5.8438
# Epoch [3/100], Avg. Loss: 5.0800
# Epoch [4/100], Avg. Loss: 4.8583
# Epoch [5/100], Avg. Loss: 4.7351
# Epoch [6/100], Avg. Loss: 4.6461
# Epoch [7/100], Avg. Loss: 4.5881
# Epoch [8/100], Avg. Loss: 4.5404
# Epoch [9/100], Avg. Loss: 4.5023
# Epoch [10/100], Avg. Loss: 4.4676
# Epoch [11/100], Avg. Loss: 4.4399
# Epoch [12/100], Avg. Loss: 4.4163
# Epoch [13/100], Avg. Loss: 4.3945
# Epoch [14/100], Avg. Loss: 4.3754
# Epoch [15/100], Avg. Loss: 4.3567
# Epoch [16/100], Avg. Loss: 4.3409
# Epoch [17/100], Avg. Loss: 4.3272
# Epoch [18/100], Avg. Loss: 4.3131
# Epoch [19/100], Avg. Loss: 4.3002
# Epoch [20/100], Avg. Loss: 4.2871
# Epoch [21/100], Avg. Loss: 4.2749
# Epoch [22/100], Avg. Loss: 4.2627
# Epoch [23/100], Avg. Loss: 4.2527
# Epoch [24/100], Avg. Loss: 4.2430
# Epoch [25/100], Avg. Loss: 4.2333
# Epoch [26/100], Avg. Loss: 4.2225
# Epoch [27/100], Avg. Loss: 4.2140
# Epoch [28/100], Avg. Loss: 4.2058
# Epoch [29/100], Avg. Loss: 4.2009
# Epoch [30/100], Avg. Loss: 4.1929
# Epoch [31/100], Avg. Loss: 4.1862
# Epoch [32/100], Avg. Loss: 4.1807
# Epoch [33/100], Avg. Loss: 4.1732
# Epoch [34/100], Avg. Loss: 4.1673
# Epoch [35/100], Avg. Loss: 4.1628
# Epoch [36/100], Avg. Loss: 4.1575
# Epoch [37/100], Avg. Loss: 4.1531
# Epoch [38/100], Avg. Loss: 4.1485
# Epoch [39/100], Avg. Loss: 4.1447
# Epoch [40/100], Avg. Loss: 4.1408
# Epoch [41/100], Avg. Loss: 4.1376
# Epoch [42/100], Avg. Loss: 4.1338
# Epoch [43/100], Avg. Loss: 4.1305
# Epoch [44/100], Avg. Loss: 4.1268
# Epoch [45/100], Avg. Loss: 4.1235
# Epoch [46/100], Avg. Loss: 4.1198
# Epoch [47/100], Avg. Loss: 4.1156
# Epoch [48/100], Avg. Loss: 4.1123
# Epoch [49/100], Avg. Loss: 4.1088
# Epoch [50/100], Avg. Loss: 4.1058
# Epoch [51/100], Avg. Loss: 4.1033
# Epoch [52/100], Avg. Loss: 4.1005
# Epoch [53/100], Avg. Loss: 4.0980
# Epoch [54/100], Avg. Loss: 4.0948
# Epoch [55/100], Avg. Loss: 4.0917
# Epoch [56/100], Avg. Loss: 4.0890
# Epoch [57/100], Avg. Loss: 4.0865
# Epoch [58/100], Avg. Loss: 4.0830
# Epoch [59/100], Avg. Loss: 4.0807
# Epoch [60/100], Avg. Loss: 4.0779
# Epoch [61/100], Avg. Loss: 4.0754
# Epoch [62/100], Avg. Loss: 4.0722
# Epoch [63/100], Avg. Loss: 4.0699
# Epoch [64/100], Avg. Loss: 4.0667
# Epoch [65/100], Avg. Loss: 4.0648
# Epoch [66/100], Avg. Loss: 4.0622
# Epoch [67/100], Avg. Loss: 4.0609
# Epoch [68/100], Avg. Loss: 4.0580
# Epoch [69/100], Avg. Loss: 4.0559
# Epoch [70/100], Avg. Loss: 4.0531
# Epoch [71/100], Avg. Loss: 4.0506
# Epoch [72/100], Avg. Loss: 4.0483
# Epoch [73/100], Avg. Loss: 4.0473
# Epoch [74/100], Avg. Loss: 4.0445
# Epoch [75/100], Avg. Loss: 4.0424
# Epoch [76/100], Avg. Loss: 4.0406
# Epoch [77/100], Avg. Loss: 4.0382
# Epoch [78/100], Avg. Loss: 4.0361
# Epoch [79/100], Avg. Loss: 4.0337
# Epoch [80/100], Avg. Loss: 4.0313
# Epoch [81/100], Avg. Loss: 4.0301
# Epoch [82/100], Avg. Loss: 4.0278
# Epoch [83/100], Avg. Loss: 4.0264
# Epoch [84/100], Avg. Loss: 4.0245
# Epoch [85/100], Avg. Loss: 4.0224
# Epoch [86/100], Avg. Loss: 4.0203
# Epoch [87/100], Avg. Loss: 4.0179
# Epoch [88/100], Avg. Loss: 4.0162
# Epoch [89/100], Avg. Loss: 4.0139
# Epoch [90/100], Avg. Loss: 4.0123
# Epoch [91/100], Avg. Loss: 4.0103
# Epoch [92/100], Avg. Loss: 4.0088
# Epoch [93/100], Avg. Loss: 4.0064
# Epoch [94/100], Avg. Loss: 4.0055
# Epoch [95/100], Avg. Loss: 4.0041
# Epoch [96/100], Avg. Loss: 4.0024
# Epoch [97/100], Avg. Loss: 4.0014
# Epoch [98/100], Avg. Loss: 3.9990
# Epoch [99/100], Avg. Loss: 3.9979
# Epoch [100/100], Avg. Loss: 3.9966
# Epoch [1/100], Avg. Loss: 40.6964
# Epoch [2/100], Avg. Loss: 5.5036
# Epoch [3/100], Avg. Loss: 4.8375
# Epoch [4/100], Avg. Loss: 4.6270
# Epoch [5/100], Avg. Loss: 4.5483
# Epoch [6/100], Avg. Loss: 4.4760
# Epoch [7/100], Avg. Loss: 4.4398
# Epoch [8/100], Avg. Loss: 4.4015
# Epoch [9/100], Avg. Loss: 4.3706
# Epoch [10/100], Avg. Loss: 4.3479
# Epoch [11/100], Avg. Loss: 4.3237
# Epoch [12/100], Avg. Loss: 4.3049
# Epoch [13/100], Avg. Loss: 4.2852
# Epoch [14/100], Avg. Loss: 4.2702
# Epoch [15/100], Avg. Loss: 4.2563
# Epoch [16/100], Avg. Loss: 4.2427
# Epoch [17/100], Avg. Loss: 4.2298
# Epoch [18/100], Avg. Loss: 4.2188
# Epoch [19/100], Avg. Loss: 4.2079
# Epoch [20/100], Avg. Loss: 4.1981
# Epoch [21/100], Avg. Loss: 4.1874
# Epoch [22/100], Avg. Loss: 4.1792
# Epoch [23/100], Avg. Loss: 4.1698
# Epoch [24/100], Avg. Loss: 4.1606
# Epoch [25/100], Avg. Loss: 4.1510
# Epoch [26/100], Avg. Loss: 4.1437
# Epoch [27/100], Avg. Loss: 4.1357
# Epoch [28/100], Avg. Loss: 4.1302
# Epoch [29/100], Avg. Loss: 4.1252
# Epoch [30/100], Avg. Loss: 4.1124
# Epoch [31/100], Avg. Loss: 4.1071
# Epoch [32/100], Avg. Loss: 4.0991
# Epoch [33/100], Avg. Loss: 4.0947
# Epoch [34/100], Avg. Loss: 4.0874
# Epoch [35/100], Avg. Loss: 4.0823
# Epoch [36/100], Avg. Loss: 4.0776
# Epoch [37/100], Avg. Loss: 4.0722
# Epoch [38/100], Avg. Loss: 4.0681
# Epoch [39/100], Avg. Loss: 4.0639
# Epoch [40/100], Avg. Loss: 4.0604
# Epoch [41/100], Avg. Loss: 4.0568
# Epoch [42/100], Avg. Loss: 4.0548
# Epoch [43/100], Avg. Loss: 4.0483
# Epoch [44/100], Avg. Loss: 4.0443
# Epoch [45/100], Avg. Loss: 4.0426
# Epoch [46/100], Avg. Loss: 4.0379
# Epoch [47/100], Avg. Loss: 4.0340
# Epoch [48/100], Avg. Loss: 4.0309
# Epoch [49/100], Avg. Loss: 4.0271
# Epoch [50/100], Avg. Loss: 4.0234
# Epoch [51/100], Avg. Loss: 4.0197
# Epoch [52/100], Avg. Loss: 4.0175
# Epoch [53/100], Avg. Loss: 4.0139
# Epoch [54/100], Avg. Loss: 4.0105
# Epoch [55/100], Avg. Loss: 4.0061
# Epoch [56/100], Avg. Loss: 4.0025
# Epoch [57/100], Avg. Loss: 3.9996
# Epoch [58/100], Avg. Loss: 3.9959
# Epoch [59/100], Avg. Loss: 3.9933
# Epoch [60/100], Avg. Loss: 3.9906
# Epoch [61/100], Avg. Loss: 3.9874
# Epoch [62/100], Avg. Loss: 3.9838
# Epoch [63/100], Avg. Loss: 3.9806
# Epoch [64/100], Avg. Loss: 3.9777
# Epoch [65/100], Avg. Loss: 3.9737
# Epoch [66/100], Avg. Loss: 3.9685
# Epoch [67/100], Avg. Loss: 3.9646
# Epoch [68/100], Avg. Loss: 3.9610
# Epoch [69/100], Avg. Loss: 3.9559
# Epoch [70/100], Avg. Loss: 3.9529
# Epoch [71/100], Avg. Loss: 3.9491
# Epoch [72/100], Avg. Loss: 3.9450
# Epoch [73/100], Avg. Loss: 3.9408
# Epoch [74/100], Avg. Loss: 3.9398
# Epoch [75/100], Avg. Loss: 3.9336
# Epoch [76/100], Avg. Loss: 3.9330
# Epoch [77/100], Avg. Loss: 3.9301
# Epoch [78/100], Avg. Loss: 3.9235
# Epoch [79/100], Avg. Loss: 3.9229
# Epoch [80/100], Avg. Loss: 3.9199
# Epoch [81/100], Avg. Loss: 3.9184
# Epoch [82/100], Avg. Loss: 3.9153
# Epoch [83/100], Avg. Loss: 3.9124
# Epoch [84/100], Avg. Loss: 3.9104
# Epoch [85/100], Avg. Loss: 3.9081
# Epoch [86/100], Avg. Loss: 3.9059
# Epoch [87/100], Avg. Loss: 3.9034
# Epoch [88/100], Avg. Loss: 3.8981
# Epoch [89/100], Avg. Loss: 3.8986
# Epoch [90/100], Avg. Loss: 3.8954
# Epoch [91/100], Avg. Loss: 3.8937
# Epoch [92/100], Avg. Loss: 3.8908
# Epoch [93/100], Avg. Loss: 3.8889
# Epoch [94/100], Avg. Loss: 3.8870
# Epoch [95/100], Avg. Loss: 3.8842
# Epoch [96/100], Avg. Loss: 3.8819
# Epoch [97/100], Avg. Loss: 3.8791
# Epoch [98/100], Avg. Loss: 3.8782
# Epoch [99/100], Avg. Loss: 3.8762
# Epoch [100/100], Avg. Loss: 3.8742
# Epoch [1/100], Avg. Loss: 50.4212
# Epoch [2/100], Avg. Loss: 6.4487
# Epoch [3/100], Avg. Loss: 5.6197
# Epoch [4/100], Avg. Loss: 5.0596
# Epoch [5/100], Avg. Loss: 4.7680
# Epoch [6/100], Avg. Loss: 4.6270
# Epoch [7/100], Avg. Loss: 4.5441
# Epoch [8/100], Avg. Loss: 4.4927
# Epoch [9/100], Avg. Loss: 4.4548
# Epoch [10/100], Avg. Loss: 4.4261
# Epoch [11/100], Avg. Loss: 4.3932
# Epoch [12/100], Avg. Loss: 4.3693
# Epoch [13/100], Avg. Loss: 4.3486
# Epoch [14/100], Avg. Loss: 4.3293
# Epoch [15/100], Avg. Loss: 4.3125
# Epoch [16/100], Avg. Loss: 4.2962
# Epoch [17/100], Avg. Loss: 4.2809
# Epoch [18/100], Avg. Loss: 4.2662
# Epoch [19/100], Avg. Loss: 4.2518
# Epoch [20/100], Avg. Loss: 4.2393
# Epoch [21/100], Avg. Loss: 4.2273
# Epoch [22/100], Avg. Loss: 4.2155
# Epoch [23/100], Avg. Loss: 4.2053
# Epoch [24/100], Avg. Loss: 4.1947
# Epoch [25/100], Avg. Loss: 4.1843
# Epoch [26/100], Avg. Loss: 4.1751
# Epoch [27/100], Avg. Loss: 4.1644
# Epoch [28/100], Avg. Loss: 4.1559
# Epoch [29/100], Avg. Loss: 4.1473
# Epoch [30/100], Avg. Loss: 4.1401
# Epoch [31/100], Avg. Loss: 4.1336
# Epoch [32/100], Avg. Loss: 4.1265
# Epoch [33/100], Avg. Loss: 4.1211
# Epoch [34/100], Avg. Loss: 4.1150
# Epoch [35/100], Avg. Loss: 4.1099
# Epoch [36/100], Avg. Loss: 4.1030
# Epoch [37/100], Avg. Loss: 4.0967
# Epoch [38/100], Avg. Loss: 4.0916
# Epoch [39/100], Avg. Loss: 4.0861
# Epoch [40/100], Avg. Loss: 4.0796
# Epoch [41/100], Avg. Loss: 4.0746
# Epoch [42/100], Avg. Loss: 4.0705
# Epoch [43/100], Avg. Loss: 4.0654
# Epoch [44/100], Avg. Loss: 4.0614
# Epoch [45/100], Avg. Loss: 4.0572
# Epoch [46/100], Avg. Loss: 4.0525
# Epoch [47/100], Avg. Loss: 4.0483
# Epoch [48/100], Avg. Loss: 4.0458
# Epoch [49/100], Avg. Loss: 4.0387
# Epoch [50/100], Avg. Loss: 4.0356
# Epoch [51/100], Avg. Loss: 4.0310
# Epoch [52/100], Avg. Loss: 4.0280
# Epoch [53/100], Avg. Loss: 4.0249
# Epoch [54/100], Avg. Loss: 4.0193
# Epoch [55/100], Avg. Loss: 4.0154
# Epoch [56/100], Avg. Loss: 4.0105
# Epoch [57/100], Avg. Loss: 4.0058
# Epoch [58/100], Avg. Loss: 4.0028
# Epoch [59/100], Avg. Loss: 3.9999
# Epoch [60/100], Avg. Loss: 3.9956
# Epoch [61/100], Avg. Loss: 3.9913
# Epoch [62/100], Avg. Loss: 3.9841
# Epoch [63/100], Avg. Loss: 3.9818
# Epoch [64/100], Avg. Loss: 3.9793
# Epoch [65/100], Avg. Loss: 3.9745
# Epoch [66/100], Avg. Loss: 3.9714
# Epoch [67/100], Avg. Loss: 3.9681
# Epoch [68/100], Avg. Loss: 3.9666
# Epoch [69/100], Avg. Loss: 3.9619
# Epoch [70/100], Avg. Loss: 3.9592
# Epoch [71/100], Avg. Loss: 3.9551
# Epoch [72/100], Avg. Loss: 3.9523
# Epoch [73/100], Avg. Loss: 3.9481
# Epoch [74/100], Avg. Loss: 3.9438
# Epoch [75/100], Avg. Loss: 3.9397
# Epoch [76/100], Avg. Loss: 3.9357
# Epoch [77/100], Avg. Loss: 3.9325
# Epoch [78/100], Avg. Loss: 3.9293
# Epoch [79/100], Avg. Loss: 3.9246
# Epoch [80/100], Avg. Loss: 3.9227
# Epoch [81/100], Avg. Loss: 3.9181
# Epoch [82/100], Avg. Loss: 3.9129
# Epoch [83/100], Avg. Loss: 3.9090
# Epoch [84/100], Avg. Loss: 3.9064
# Epoch [85/100], Avg. Loss: 3.9042
# Epoch [86/100], Avg. Loss: 3.9003
# Epoch [87/100], Avg. Loss: 3.8964
# Epoch [88/100], Avg. Loss: 3.8941
# Epoch [89/100], Avg. Loss: 3.8909
# Epoch [90/100], Avg. Loss: 3.8841
# Epoch [91/100], Avg. Loss: 3.8820
# Epoch [92/100], Avg. Loss: 3.8744
# Epoch [93/100], Avg. Loss: 3.8705
# Epoch [94/100], Avg. Loss: 3.8693
# Epoch [95/100], Avg. Loss: 3.8614
# Epoch [96/100], Avg. Loss: 3.8596
# Epoch [97/100], Avg. Loss: 3.8548
# Epoch [98/100], Avg. Loss: 3.8511
# Epoch [99/100], Avg. Loss: 3.8477
# Epoch [100/100], Avg. Loss: 3.8455
# Epoch [1/100], Avg. Loss: 24.3258
# Epoch [2/100], Avg. Loss: 5.5478
# Epoch [3/100], Avg. Loss: 4.9889
# Epoch [4/100], Avg. Loss: 4.8155
# Epoch [5/100], Avg. Loss: 4.7014
# Epoch [6/100], Avg. Loss: 4.6320
# Epoch [7/100], Avg. Loss: 4.5851
# Epoch [8/100], Avg. Loss: 4.5511
# Epoch [9/100], Avg. Loss: 4.5233
# Epoch [10/100], Avg. Loss: 4.4979
# Epoch [11/100], Avg. Loss: 4.4763
# Epoch [12/100], Avg. Loss: 4.4574
# Epoch [13/100], Avg. Loss: 4.4380
# Epoch [14/100], Avg. Loss: 4.4221
# Epoch [15/100], Avg. Loss: 4.4052
# Epoch [16/100], Avg. Loss: 4.3925
# Epoch [17/100], Avg. Loss: 4.3772
# Epoch [18/100], Avg. Loss: 4.3643
# Epoch [19/100], Avg. Loss: 4.3501
# Epoch [20/100], Avg. Loss: 4.3379
# Epoch [21/100], Avg. Loss: 4.3257
# Epoch [22/100], Avg. Loss: 4.3135
# Epoch [23/100], Avg. Loss: 4.3022
# Epoch [24/100], Avg. Loss: 4.2906
# Epoch [25/100], Avg. Loss: 4.2807
# Epoch [26/100], Avg. Loss: 4.2724
# Epoch [27/100], Avg. Loss: 4.2645
# Epoch [28/100], Avg. Loss: 4.2567
# Epoch [29/100], Avg. Loss: 4.2491
# Epoch [30/100], Avg. Loss: 4.2423
# Epoch [31/100], Avg. Loss: 4.2359
# Epoch [32/100], Avg. Loss: 4.2298
# Epoch [33/100], Avg. Loss: 4.2242
# Epoch [34/100], Avg. Loss: 4.2184
# Epoch [35/100], Avg. Loss: 4.2133
# Epoch [36/100], Avg. Loss: 4.2083
# Epoch [37/100], Avg. Loss: 4.2035
# Epoch [38/100], Avg. Loss: 4.1990
# Epoch [39/100], Avg. Loss: 4.1950
# Epoch [40/100], Avg. Loss: 4.1912
# Epoch [41/100], Avg. Loss: 4.1872
# Epoch [42/100], Avg. Loss: 4.1834
# Epoch [43/100], Avg. Loss: 4.1795
# Epoch [44/100], Avg. Loss: 4.1757
# Epoch [45/100], Avg. Loss: 4.1721
# Epoch [46/100], Avg. Loss: 4.1684
# Epoch [47/100], Avg. Loss: 4.1649
# Epoch [48/100], Avg. Loss: 4.1613
# Epoch [49/100], Avg. Loss: 4.1583
# Epoch [50/100], Avg. Loss: 4.1551
# Epoch [51/100], Avg. Loss: 4.1520
# Epoch [52/100], Avg. Loss: 4.1489
# Epoch [53/100], Avg. Loss: 4.1460
# Epoch [54/100], Avg. Loss: 4.1430
# Epoch [55/100], Avg. Loss: 4.1402
# Epoch [56/100], Avg. Loss: 4.1373
# Epoch [57/100], Avg. Loss: 4.1342
# Epoch [58/100], Avg. Loss: 4.1314
# Epoch [59/100], Avg. Loss: 4.1288
# Epoch [60/100], Avg. Loss: 4.1261
# Epoch [61/100], Avg. Loss: 4.1234
# Epoch [62/100], Avg. Loss: 4.1203
# Epoch [63/100], Avg. Loss: 4.1178
# Epoch [64/100], Avg. Loss: 4.1146
# Epoch [65/100], Avg. Loss: 4.1123
# Epoch [66/100], Avg. Loss: 4.1092
# Epoch [67/100], Avg. Loss: 4.1065
# Epoch [68/100], Avg. Loss: 4.1038
# Epoch [69/100], Avg. Loss: 4.1009
# Epoch [70/100], Avg. Loss: 4.0989
# Epoch [71/100], Avg. Loss: 4.0961
# Epoch [72/100], Avg. Loss: 4.0936
# Epoch [73/100], Avg. Loss: 4.0912
# Epoch [74/100], Avg. Loss: 4.0885
# Epoch [75/100], Avg. Loss: 4.0857
# Epoch [76/100], Avg. Loss: 4.0833
# Epoch [77/100], Avg. Loss: 4.0806
# Epoch [78/100], Avg. Loss: 4.0779
# Epoch [79/100], Avg. Loss: 4.0754
# Epoch [80/100], Avg. Loss: 4.0727
# Epoch [81/100], Avg. Loss: 4.0699
# Epoch [82/100], Avg. Loss: 4.0674
# Epoch [83/100], Avg. Loss: 4.0655
# Epoch [84/100], Avg. Loss: 4.0635
# Epoch [85/100], Avg. Loss: 4.0605
# Epoch [86/100], Avg. Loss: 4.0588
# Epoch [87/100], Avg. Loss: 4.0561
# Epoch [88/100], Avg. Loss: 4.0535
# Epoch [89/100], Avg. Loss: 4.0511
# Epoch [90/100], Avg. Loss: 4.0488
# Epoch [91/100], Avg. Loss: 4.0461
# Epoch [92/100], Avg. Loss: 4.0436
# Epoch [93/100], Avg. Loss: 4.0416
# Epoch [94/100], Avg. Loss: 4.0396
# Epoch [95/100], Avg. Loss: 4.0371
# Epoch [96/100], Avg. Loss: 4.0349
# Epoch [97/100], Avg. Loss: 4.0327
# Epoch [98/100], Avg. Loss: 4.0306
# Epoch [99/100], Avg. Loss: 4.0284
# Epoch [100/100], Avg. Loss: 4.0256
# Epoch [1/100], Avg. Loss: 25.5237
# Epoch [2/100], Avg. Loss: 5.3666
# Epoch [3/100], Avg. Loss: 4.9049
# Epoch [4/100], Avg. Loss: 4.7093
# Epoch [5/100], Avg. Loss: 4.6095
# Epoch [6/100], Avg. Loss: 4.5427
# Epoch [7/100], Avg. Loss: 4.5006
# Epoch [8/100], Avg. Loss: 4.4675
# Epoch [9/100], Avg. Loss: 4.4376
# Epoch [10/100], Avg. Loss: 4.4130
# Epoch [11/100], Avg. Loss: 4.3890
# Epoch [12/100], Avg. Loss: 4.3677
# Epoch [13/100], Avg. Loss: 4.3491
# Epoch [14/100], Avg. Loss: 4.3308
# Epoch [15/100], Avg. Loss: 4.3130
# Epoch [16/100], Avg. Loss: 4.2978
# Epoch [17/100], Avg. Loss: 4.2828
# Epoch [18/100], Avg. Loss: 4.2703
# Epoch [19/100], Avg. Loss: 4.2576
# Epoch [20/100], Avg. Loss: 4.2459
# Epoch [21/100], Avg. Loss: 4.2340
# Epoch [22/100], Avg. Loss: 4.2218
# Epoch [23/100], Avg. Loss: 4.2126
# Epoch [24/100], Avg. Loss: 4.2034
# Epoch [25/100], Avg. Loss: 4.1937
# Epoch [26/100], Avg. Loss: 4.1849
# Epoch [27/100], Avg. Loss: 4.1767
# Epoch [28/100], Avg. Loss: 4.1688
# Epoch [29/100], Avg. Loss: 4.1616
# Epoch [30/100], Avg. Loss: 4.1544
# Epoch [31/100], Avg. Loss: 4.1500
# Epoch [32/100], Avg. Loss: 4.1449
# Epoch [33/100], Avg. Loss: 4.1392
# Epoch [34/100], Avg. Loss: 4.1343
# Epoch [35/100], Avg. Loss: 4.1291
# Epoch [36/100], Avg. Loss: 4.1246
# Epoch [37/100], Avg. Loss: 4.1207
# Epoch [38/100], Avg. Loss: 4.1167
# Epoch [39/100], Avg. Loss: 4.1128
# Epoch [40/100], Avg. Loss: 4.1089
# Epoch [41/100], Avg. Loss: 4.1048
# Epoch [42/100], Avg. Loss: 4.1014
# Epoch [43/100], Avg. Loss: 4.0975
# Epoch [44/100], Avg. Loss: 4.0938
# Epoch [45/100], Avg. Loss: 4.0902
# Epoch [46/100], Avg. Loss: 4.0854
# Epoch [47/100], Avg. Loss: 4.0829
# Epoch [48/100], Avg. Loss: 4.0808
# Epoch [49/100], Avg. Loss: 4.0763
# Epoch [50/100], Avg. Loss: 4.0725
# Epoch [51/100], Avg. Loss: 4.0706
# Epoch [52/100], Avg. Loss: 4.0665
# Epoch [53/100], Avg. Loss: 4.0631
# Epoch [54/100], Avg. Loss: 4.0608
# Epoch [55/100], Avg. Loss: 4.0574
# Epoch [56/100], Avg. Loss: 4.0533
# Epoch [57/100], Avg. Loss: 4.0512
# Epoch [58/100], Avg. Loss: 4.0478
# Epoch [59/100], Avg. Loss: 4.0441
# Epoch [60/100], Avg. Loss: 4.0408
# Epoch [61/100], Avg. Loss: 4.0391
# Epoch [62/100], Avg. Loss: 4.0356
# Epoch [63/100], Avg. Loss: 4.0317
# Epoch [64/100], Avg. Loss: 4.0295
# Epoch [65/100], Avg. Loss: 4.0262
# Epoch [66/100], Avg. Loss: 4.0242
# Epoch [67/100], Avg. Loss: 4.0183
# Epoch [68/100], Avg. Loss: 4.0162
# Epoch [69/100], Avg. Loss: 4.0124
# Epoch [70/100], Avg. Loss: 4.0098
# Epoch [71/100], Avg. Loss: 4.0070
# Epoch [72/100], Avg. Loss: 4.0041
# Epoch [73/100], Avg. Loss: 4.0039
# Epoch [74/100], Avg. Loss: 4.0015
# Epoch [75/100], Avg. Loss: 3.9979
# Epoch [76/100], Avg. Loss: 3.9957
# Epoch [77/100], Avg. Loss: 3.9935
# Epoch [78/100], Avg. Loss: 3.9894
# Epoch [79/100], Avg. Loss: 3.9888
# Epoch [80/100], Avg. Loss: 3.9867
# Epoch [81/100], Avg. Loss: 3.9837
# Epoch [82/100], Avg. Loss: 3.9820
# Epoch [83/100], Avg. Loss: 3.9789
# Epoch [84/100], Avg. Loss: 3.9775
# Epoch [85/100], Avg. Loss: 3.9747
# Epoch [86/100], Avg. Loss: 3.9714
# Epoch [87/100], Avg. Loss: 3.9706
# Epoch [88/100], Avg. Loss: 3.9674
# Epoch [89/100], Avg. Loss: 3.9663
# Epoch [90/100], Avg. Loss: 3.9639
# Epoch [91/100], Avg. Loss: 3.9602
# Epoch [92/100], Avg. Loss: 3.9597
# Epoch [93/100], Avg. Loss: 3.9570
# Epoch [94/100], Avg. Loss: 3.9541
# Epoch [95/100], Avg. Loss: 3.9519
# Epoch [96/100], Avg. Loss: 3.9515
# Epoch [97/100], Avg. Loss: 3.9496
# Epoch [98/100], Avg. Loss: 3.9473
# Epoch [99/100], Avg. Loss: 3.9452
# Epoch [100/100], Avg. Loss: 3.9432
# Epoch [1/100], Avg. Loss: 29.6746
# Epoch [2/100], Avg. Loss: 5.2019
# Epoch [3/100], Avg. Loss: 4.7325
# Epoch [4/100], Avg. Loss: 4.5946
# Epoch [5/100], Avg. Loss: 4.5258
# Epoch [6/100], Avg. Loss: 4.4826
# Epoch [7/100], Avg. Loss: 4.4513
# Epoch [8/100], Avg. Loss: 4.4259
# Epoch [9/100], Avg. Loss: 4.4011
# Epoch [10/100], Avg. Loss: 4.3757
# Epoch [11/100], Avg. Loss: 4.3534
# Epoch [12/100], Avg. Loss: 4.3341
# Epoch [13/100], Avg. Loss: 4.3165
# Epoch [14/100], Avg. Loss: 4.3004
# Epoch [15/100], Avg. Loss: 4.2843
# Epoch [16/100], Avg. Loss: 4.2695
# Epoch [17/100], Avg. Loss: 4.2557
# Epoch [18/100], Avg. Loss: 4.2433
# Epoch [19/100], Avg. Loss: 4.2322
# Epoch [20/100], Avg. Loss: 4.2206
# Epoch [21/100], Avg. Loss: 4.2107
# Epoch [22/100], Avg. Loss: 4.2015
# Epoch [23/100], Avg. Loss: 4.1920
# Epoch [24/100], Avg. Loss: 4.1839
# Epoch [25/100], Avg. Loss: 4.1748
# Epoch [26/100], Avg. Loss: 4.1665
# Epoch [27/100], Avg. Loss: 4.1591
# Epoch [28/100], Avg. Loss: 4.1518
# Epoch [29/100], Avg. Loss: 4.1451
# Epoch [30/100], Avg. Loss: 4.1390
# Epoch [31/100], Avg. Loss: 4.1329
# Epoch [32/100], Avg. Loss: 4.1273
# Epoch [33/100], Avg. Loss: 4.1217
# Epoch [34/100], Avg. Loss: 4.1161
# Epoch [35/100], Avg. Loss: 4.1108
# Epoch [36/100], Avg. Loss: 4.1060
# Epoch [37/100], Avg. Loss: 4.1010
# Epoch [38/100], Avg. Loss: 4.0961
# Epoch [39/100], Avg. Loss: 4.0900
# Epoch [40/100], Avg. Loss: 4.0851
# Epoch [41/100], Avg. Loss: 4.0801
# Epoch [42/100], Avg. Loss: 4.0760
# Epoch [43/100], Avg. Loss: 4.0724
# Epoch [44/100], Avg. Loss: 4.0690
# Epoch [45/100], Avg. Loss: 4.0644
# Epoch [46/100], Avg. Loss: 4.0609
# Epoch [47/100], Avg. Loss: 4.0557
# Epoch [48/100], Avg. Loss: 4.0519
# Epoch [49/100], Avg. Loss: 4.0479
# Epoch [50/100], Avg. Loss: 4.0440
# Epoch [51/100], Avg. Loss: 4.0402
# Epoch [52/100], Avg. Loss: 4.0362
# Epoch [53/100], Avg. Loss: 4.0327
# Epoch [54/100], Avg. Loss: 4.0276
# Epoch [55/100], Avg. Loss: 4.0252
# Epoch [56/100], Avg. Loss: 4.0211
# Epoch [57/100], Avg. Loss: 4.0166
# Epoch [58/100], Avg. Loss: 4.0134
# Epoch [59/100], Avg. Loss: 4.0103
# Epoch [60/100], Avg. Loss: 4.0066
# Epoch [61/100], Avg. Loss: 4.0036
# Epoch [62/100], Avg. Loss: 4.0007
# Epoch [63/100], Avg. Loss: 3.9975
# Epoch [64/100], Avg. Loss: 3.9938
# Epoch [65/100], Avg. Loss: 3.9914
# Epoch [66/100], Avg. Loss: 3.9882
# Epoch [67/100], Avg. Loss: 3.9857
# Epoch [68/100], Avg. Loss: 3.9833
# Epoch [69/100], Avg. Loss: 3.9793
# Epoch [70/100], Avg. Loss: 3.9756
# Epoch [71/100], Avg. Loss: 3.9730
# Epoch [72/100], Avg. Loss: 3.9678
# Epoch [73/100], Avg. Loss: 3.9651
# Epoch [74/100], Avg. Loss: 3.9607
# Epoch [75/100], Avg. Loss: 3.9583
# Epoch [76/100], Avg. Loss: 3.9538
# Epoch [77/100], Avg. Loss: 3.9512
# Epoch [78/100], Avg. Loss: 3.9480
# Epoch [79/100], Avg. Loss: 3.9446
# Epoch [80/100], Avg. Loss: 3.9417
# Epoch [81/100], Avg. Loss: 3.9377
# Epoch [82/100], Avg. Loss: 3.9346
# Epoch [83/100], Avg. Loss: 3.9297
# Epoch [84/100], Avg. Loss: 3.9259
# Epoch [85/100], Avg. Loss: 3.9202
# Epoch [86/100], Avg. Loss: 3.9171
# Epoch [87/100], Avg. Loss: 3.9139
# Epoch [88/100], Avg. Loss: 3.9094
# Epoch [89/100], Avg. Loss: 3.9073
# Epoch [90/100], Avg. Loss: 3.9031
# Epoch [91/100], Avg. Loss: 3.8991
# Epoch [92/100], Avg. Loss: 3.8942
# Epoch [93/100], Avg. Loss: 3.8911
# Epoch [94/100], Avg. Loss: 3.8880
# Epoch [95/100], Avg. Loss: 3.8851
# Epoch [96/100], Avg. Loss: 3.8810
# Epoch [97/100], Avg. Loss: 3.8777
# Epoch [98/100], Avg. Loss: 3.8737
# Epoch [99/100], Avg. Loss: 3.8702
# Epoch [100/100], Avg. Loss: 3.8659
# Epoch [1/100], Avg. Loss: 37.8591
# Epoch [2/100], Avg. Loss: 5.9874
# Epoch [3/100], Avg. Loss: 5.1693
# Epoch [4/100], Avg. Loss: 4.8339
# Epoch [5/100], Avg. Loss: 4.6814
# Epoch [6/100], Avg. Loss: 4.5842
# Epoch [7/100], Avg. Loss: 4.5062
# Epoch [8/100], Avg. Loss: 4.4407
# Epoch [9/100], Avg. Loss: 4.3978
# Epoch [10/100], Avg. Loss: 4.3632
# Epoch [11/100], Avg. Loss: 4.3328
# Epoch [12/100], Avg. Loss: 4.3054
# Epoch [13/100], Avg. Loss: 4.2812
# Epoch [14/100], Avg. Loss: 4.2608
# Epoch [15/100], Avg. Loss: 4.2424
# Epoch [16/100], Avg. Loss: 4.2241
# Epoch [17/100], Avg. Loss: 4.2076
# Epoch [18/100], Avg. Loss: 4.1928
# Epoch [19/100], Avg. Loss: 4.1801
# Epoch [20/100], Avg. Loss: 4.1675
# Epoch [21/100], Avg. Loss: 4.1558
# Epoch [22/100], Avg. Loss: 4.1443
# Epoch [23/100], Avg. Loss: 4.1321
# Epoch [24/100], Avg. Loss: 4.1222
# Epoch [25/100], Avg. Loss: 4.1134
# Epoch [26/100], Avg. Loss: 4.1037
# Epoch [27/100], Avg. Loss: 4.0949
# Epoch [28/100], Avg. Loss: 4.0860
# Epoch [29/100], Avg. Loss: 4.0776
# Epoch [30/100], Avg. Loss: 4.0708
# Epoch [31/100], Avg. Loss: 4.0630
# Epoch [32/100], Avg. Loss: 4.0562
# Epoch [33/100], Avg. Loss: 4.0495
# Epoch [34/100], Avg. Loss: 4.0436
# Epoch [35/100], Avg. Loss: 4.0379
# Epoch [36/100], Avg. Loss: 4.0310
# Epoch [37/100], Avg. Loss: 4.0227
# Epoch [38/100], Avg. Loss: 4.0179
# Epoch [39/100], Avg. Loss: 4.0107
# Epoch [40/100], Avg. Loss: 4.0046
# Epoch [41/100], Avg. Loss: 3.9994
# Epoch [42/100], Avg. Loss: 3.9933
# Epoch [43/100], Avg. Loss: 3.9885
# Epoch [44/100], Avg. Loss: 3.9831
# Epoch [45/100], Avg. Loss: 3.9778
# Epoch [46/100], Avg. Loss: 3.9715
# Epoch [47/100], Avg. Loss: 3.9690
# Epoch [48/100], Avg. Loss: 3.9626
# Epoch [49/100], Avg. Loss: 3.9567
# Epoch [50/100], Avg. Loss: 3.9526
# Epoch [51/100], Avg. Loss: 3.9451
# Epoch [52/100], Avg. Loss: 3.9429
# Epoch [53/100], Avg. Loss: 3.9335
# Epoch [54/100], Avg. Loss: 3.9313
# Epoch [55/100], Avg. Loss: 3.9243
# Epoch [56/100], Avg. Loss: 3.9183
# Epoch [57/100], Avg. Loss: 3.9129
# Epoch [58/100], Avg. Loss: 3.9090
# Epoch [59/100], Avg. Loss: 3.9031
# Epoch [60/100], Avg. Loss: 3.8987
# Epoch [61/100], Avg. Loss: 3.8939
# Epoch [62/100], Avg. Loss: 3.8867
# Epoch [63/100], Avg. Loss: 3.8827
# Epoch [64/100], Avg. Loss: 3.8780
# Epoch [65/100], Avg. Loss: 3.8744
# Epoch [66/100], Avg. Loss: 3.8684
# Epoch [67/100], Avg. Loss: 3.8642
# Epoch [68/100], Avg. Loss: 3.8580
# Epoch [69/100], Avg. Loss: 3.8527
# Epoch [70/100], Avg. Loss: 3.8483
# Epoch [71/100], Avg. Loss: 3.8415
# Epoch [72/100], Avg. Loss: 3.8381
# Epoch [73/100], Avg. Loss: 3.8342
# Epoch [74/100], Avg. Loss: 3.8283
# Epoch [75/100], Avg. Loss: 3.8235
# Epoch [76/100], Avg. Loss: 3.8193
# Epoch [77/100], Avg. Loss: 3.8142
# Epoch [78/100], Avg. Loss: 3.8106
# Epoch [79/100], Avg. Loss: 3.8046
# Epoch [80/100], Avg. Loss: 3.7997
# Epoch [81/100], Avg. Loss: 3.7937
# Epoch [82/100], Avg. Loss: 3.7892
# Epoch [83/100], Avg. Loss: 3.7867
# Epoch [84/100], Avg. Loss: 3.7818
# Epoch [85/100], Avg. Loss: 3.7769
# Epoch [86/100], Avg. Loss: 3.7716
# Epoch [87/100], Avg. Loss: 3.7662
# Epoch [88/100], Avg. Loss: 3.7633
# Epoch [89/100], Avg. Loss: 3.7574
# Epoch [90/100], Avg. Loss: 3.7517
# Epoch [91/100], Avg. Loss: 3.7496
# Epoch [92/100], Avg. Loss: 3.7415
# Epoch [93/100], Avg. Loss: 3.7412
# Epoch [94/100], Avg. Loss: 3.7350
# Epoch [95/100], Avg. Loss: 3.7294
# Epoch [96/100], Avg. Loss: 3.7265
# Epoch [97/100], Avg. Loss: 3.7233
# Epoch [98/100], Avg. Loss: 3.7186
# Epoch [99/100], Avg. Loss: 3.7143
# Epoch [100/100], Avg. Loss: 3.7108
# Epoch [1/100], Avg. Loss: 21.3986
# Epoch [2/100], Avg. Loss: 5.5473
# Epoch [3/100], Avg. Loss: 4.9505
# Epoch [4/100], Avg. Loss: 4.7270
# Epoch [5/100], Avg. Loss: 4.6046
# Epoch [6/100], Avg. Loss: 4.5300
# Epoch [7/100], Avg. Loss: 4.4777
# Epoch [8/100], Avg. Loss: 4.4400
# Epoch [9/100], Avg. Loss: 4.4093
# Epoch [10/100], Avg. Loss: 4.3838
# Epoch [11/100], Avg. Loss: 4.3621
# Epoch [12/100], Avg. Loss: 4.3422
# Epoch [13/100], Avg. Loss: 4.3234
# Epoch [14/100], Avg. Loss: 4.3045
# Epoch [15/100], Avg. Loss: 4.2877
# Epoch [16/100], Avg. Loss: 4.2736
# Epoch [17/100], Avg. Loss: 4.2610
# Epoch [18/100], Avg. Loss: 4.2488
# Epoch [19/100], Avg. Loss: 4.2378
# Epoch [20/100], Avg. Loss: 4.2276
# Epoch [21/100], Avg. Loss: 4.2183
# Epoch [22/100], Avg. Loss: 4.2095
# Epoch [23/100], Avg. Loss: 4.2015
# Epoch [24/100], Avg. Loss: 4.1938
# Epoch [25/100], Avg. Loss: 4.1865
# Epoch [26/100], Avg. Loss: 4.1798
# Epoch [27/100], Avg. Loss: 4.1726
# Epoch [28/100], Avg. Loss: 4.1663
# Epoch [29/100], Avg. Loss: 4.1598
# Epoch [30/100], Avg. Loss: 4.1538
# Epoch [31/100], Avg. Loss: 4.1479
# Epoch [32/100], Avg. Loss: 4.1425
# Epoch [33/100], Avg. Loss: 4.1372
# Epoch [34/100], Avg. Loss: 4.1324
# Epoch [35/100], Avg. Loss: 4.1276
# Epoch [36/100], Avg. Loss: 4.1236
# Epoch [37/100], Avg. Loss: 4.1188
# Epoch [38/100], Avg. Loss: 4.1149
# Epoch [39/100], Avg. Loss: 4.1106
# Epoch [40/100], Avg. Loss: 4.1068
# Epoch [41/100], Avg. Loss: 4.1028
# Epoch [42/100], Avg. Loss: 4.0991
# Epoch [43/100], Avg. Loss: 4.0951
# Epoch [44/100], Avg. Loss: 4.0920
# Epoch [45/100], Avg. Loss: 4.0883
# Epoch [46/100], Avg. Loss: 4.0846
# Epoch [47/100], Avg. Loss: 4.0814
# Epoch [48/100], Avg. Loss: 4.0781
# Epoch [49/100], Avg. Loss: 4.0749
# Epoch [50/100], Avg. Loss: 4.0718
# Epoch [51/100], Avg. Loss: 4.0686
# Epoch [52/100], Avg. Loss: 4.0657
# Epoch [53/100], Avg. Loss: 4.0625
# Epoch [54/100], Avg. Loss: 4.0597
# Epoch [55/100], Avg. Loss: 4.0568
# Epoch [56/100], Avg. Loss: 4.0540
# Epoch [57/100], Avg. Loss: 4.0515
# Epoch [58/100], Avg. Loss: 4.0484
# Epoch [59/100], Avg. Loss: 4.0455
# Epoch [60/100], Avg. Loss: 4.0430
# Epoch [61/100], Avg. Loss: 4.0403
# Epoch [62/100], Avg. Loss: 4.0381
# Epoch [63/100], Avg. Loss: 4.0353
# Epoch [64/100], Avg. Loss: 4.0329
# Epoch [65/100], Avg. Loss: 4.0304
# Epoch [66/100], Avg. Loss: 4.0278
# Epoch [67/100], Avg. Loss: 4.0253
# Epoch [68/100], Avg. Loss: 4.0221
# Epoch [69/100], Avg. Loss: 4.0193
# Epoch [70/100], Avg. Loss: 4.0170
# Epoch [71/100], Avg. Loss: 4.0145
# Epoch [72/100], Avg. Loss: 4.0122
# Epoch [73/100], Avg. Loss: 4.0096
# Epoch [74/100], Avg. Loss: 4.0071
# Epoch [75/100], Avg. Loss: 4.0047
# Epoch [76/100], Avg. Loss: 4.0026
# Epoch [77/100], Avg. Loss: 4.0001
# Epoch [78/100], Avg. Loss: 3.9977
# Epoch [79/100], Avg. Loss: 3.9954
# Epoch [80/100], Avg. Loss: 3.9934
# Epoch [81/100], Avg. Loss: 3.9909
# Epoch [82/100], Avg. Loss: 3.9889
# Epoch [83/100], Avg. Loss: 3.9867
# Epoch [84/100], Avg. Loss: 3.9846
# Epoch [85/100], Avg. Loss: 3.9822
# Epoch [86/100], Avg. Loss: 3.9805
# Epoch [87/100], Avg. Loss: 3.9782
# Epoch [88/100], Avg. Loss: 3.9763
# Epoch [89/100], Avg. Loss: 3.9736
# Epoch [90/100], Avg. Loss: 3.9717
# Epoch [91/100], Avg. Loss: 3.9697
# Epoch [92/100], Avg. Loss: 3.9678
# Epoch [93/100], Avg. Loss: 3.9653
# Epoch [94/100], Avg. Loss: 3.9636
# Epoch [95/100], Avg. Loss: 3.9610
# Epoch [96/100], Avg. Loss: 3.9594
# Epoch [97/100], Avg. Loss: 3.9570
# Epoch [98/100], Avg. Loss: 3.9551
# Epoch [99/100], Avg. Loss: 3.9530
# Epoch [100/100], Avg. Loss: 3.9512
# Epoch [1/100], Avg. Loss: 23.3604
# Epoch [2/100], Avg. Loss: 5.2481
# Epoch [3/100], Avg. Loss: 4.8767
# Epoch [4/100], Avg. Loss: 4.7409
# Epoch [5/100], Avg. Loss: 4.6566
# Epoch [6/100], Avg. Loss: 4.5986
# Epoch [7/100], Avg. Loss: 4.5527
# Epoch [8/100], Avg. Loss: 4.5115
# Epoch [9/100], Avg. Loss: 4.4756
# Epoch [10/100], Avg. Loss: 4.4441
# Epoch [11/100], Avg. Loss: 4.4146
# Epoch [12/100], Avg. Loss: 4.3878
# Epoch [13/100], Avg. Loss: 4.3608
# Epoch [14/100], Avg. Loss: 4.3379
# Epoch [15/100], Avg. Loss: 4.3163
# Epoch [16/100], Avg. Loss: 4.2970
# Epoch [17/100], Avg. Loss: 4.2795
# Epoch [18/100], Avg. Loss: 4.2637
# Epoch [19/100], Avg. Loss: 4.2499
# Epoch [20/100], Avg. Loss: 4.2373
# Epoch [21/100], Avg. Loss: 4.2260
# Epoch [22/100], Avg. Loss: 4.2146
# Epoch [23/100], Avg. Loss: 4.2045
# Epoch [24/100], Avg. Loss: 4.1951
# Epoch [25/100], Avg. Loss: 4.1874
# Epoch [26/100], Avg. Loss: 4.1787
# Epoch [27/100], Avg. Loss: 4.1707
# Epoch [28/100], Avg. Loss: 4.1650
# Epoch [29/100], Avg. Loss: 4.1592
# Epoch [30/100], Avg. Loss: 4.1527
# Epoch [31/100], Avg. Loss: 4.1470
# Epoch [32/100], Avg. Loss: 4.1412
# Epoch [33/100], Avg. Loss: 4.1351
# Epoch [34/100], Avg. Loss: 4.1304
# Epoch [35/100], Avg. Loss: 4.1235
# Epoch [36/100], Avg. Loss: 4.1197
# Epoch [37/100], Avg. Loss: 4.1147
# Epoch [38/100], Avg. Loss: 4.1097
# Epoch [39/100], Avg. Loss: 4.1036
# Epoch [40/100], Avg. Loss: 4.1009
# Epoch [41/100], Avg. Loss: 4.0958
# Epoch [42/100], Avg. Loss: 4.0917
# Epoch [43/100], Avg. Loss: 4.0877
# Epoch [44/100], Avg. Loss: 4.0835
# Epoch [45/100], Avg. Loss: 4.0807
# Epoch [46/100], Avg. Loss: 4.0777
# Epoch [47/100], Avg. Loss: 4.0742
# Epoch [48/100], Avg. Loss: 4.0708
# Epoch [49/100], Avg. Loss: 4.0676
# Epoch [50/100], Avg. Loss: 4.0642
# Epoch [51/100], Avg. Loss: 4.0612
# Epoch [52/100], Avg. Loss: 4.0577
# Epoch [53/100], Avg. Loss: 4.0548
# Epoch [54/100], Avg. Loss: 4.0513
# Epoch [55/100], Avg. Loss: 4.0492
# Epoch [56/100], Avg. Loss: 4.0461
# Epoch [57/100], Avg. Loss: 4.0436
# Epoch [58/100], Avg. Loss: 4.0401
# Epoch [59/100], Avg. Loss: 4.0377
# Epoch [60/100], Avg. Loss: 4.0338
# Epoch [61/100], Avg. Loss: 4.0311
# Epoch [62/100], Avg. Loss: 4.0278
# Epoch [63/100], Avg. Loss: 4.0252
# Epoch [64/100], Avg. Loss: 4.0224
# Epoch [65/100], Avg. Loss: 4.0192
# Epoch [66/100], Avg. Loss: 4.0164
# Epoch [67/100], Avg. Loss: 4.0147
# Epoch [68/100], Avg. Loss: 4.0115
# Epoch [69/100], Avg. Loss: 4.0086
# Epoch [70/100], Avg. Loss: 4.0059
# Epoch [71/100], Avg. Loss: 4.0034
# Epoch [72/100], Avg. Loss: 4.0004
# Epoch [73/100], Avg. Loss: 3.9979
# Epoch [74/100], Avg. Loss: 3.9954
# Epoch [75/100], Avg. Loss: 3.9927
# Epoch [76/100], Avg. Loss: 3.9897
# Epoch [77/100], Avg. Loss: 3.9863
# Epoch [78/100], Avg. Loss: 3.9840
# Epoch [79/100], Avg. Loss: 3.9811
# Epoch [80/100], Avg. Loss: 3.9786
# Epoch [81/100], Avg. Loss: 3.9763
# Epoch [82/100], Avg. Loss: 3.9737
# Epoch [83/100], Avg. Loss: 3.9709
# Epoch [84/100], Avg. Loss: 3.9680
# Epoch [85/100], Avg. Loss: 3.9652
# Epoch [86/100], Avg. Loss: 3.9632
# Epoch [87/100], Avg. Loss: 3.9601
# Epoch [88/100], Avg. Loss: 3.9572
# Epoch [89/100], Avg. Loss: 3.9550
# Epoch [90/100], Avg. Loss: 3.9525
# Epoch [91/100], Avg. Loss: 3.9494
# Epoch [92/100], Avg. Loss: 3.9475
# Epoch [93/100], Avg. Loss: 3.9444
# Epoch [94/100], Avg. Loss: 3.9416
# Epoch [95/100], Avg. Loss: 3.9388
# Epoch [96/100], Avg. Loss: 3.9359
# Epoch [97/100], Avg. Loss: 3.9330
# Epoch [98/100], Avg. Loss: 3.9302
# Epoch [99/100], Avg. Loss: 3.9274
# Epoch [100/100], Avg. Loss: 3.9243
# Epoch [1/100], Avg. Loss: 29.3529
# Epoch [2/100], Avg. Loss: 5.4141
# Epoch [3/100], Avg. Loss: 4.9057
# Epoch [4/100], Avg. Loss: 4.7455
# Epoch [5/100], Avg. Loss: 4.6498
# Epoch [6/100], Avg. Loss: 4.5839
# Epoch [7/100], Avg. Loss: 4.5347
# Epoch [8/100], Avg. Loss: 4.4903
# Epoch [9/100], Avg. Loss: 4.4539
# Epoch [10/100], Avg. Loss: 4.4223
# Epoch [11/100], Avg. Loss: 4.3912
# Epoch [12/100], Avg. Loss: 4.3651
# Epoch [13/100], Avg. Loss: 4.3410
# Epoch [14/100], Avg. Loss: 4.3196
# Epoch [15/100], Avg. Loss: 4.2978
# Epoch [16/100], Avg. Loss: 4.2785
# Epoch [17/100], Avg. Loss: 4.2604
# Epoch [18/100], Avg. Loss: 4.2439
# Epoch [19/100], Avg. Loss: 4.2286
# Epoch [20/100], Avg. Loss: 4.2149
# Epoch [21/100], Avg. Loss: 4.2016
# Epoch [22/100], Avg. Loss: 4.1884
# Epoch [23/100], Avg. Loss: 4.1761
# Epoch [24/100], Avg. Loss: 4.1654
# Epoch [25/100], Avg. Loss: 4.1547
# Epoch [26/100], Avg. Loss: 4.1450
# Epoch [27/100], Avg. Loss: 4.1356
# Epoch [28/100], Avg. Loss: 4.1263
# Epoch [29/100], Avg. Loss: 4.1173
# Epoch [30/100], Avg. Loss: 4.1092
# Epoch [31/100], Avg. Loss: 4.1009
# Epoch [32/100], Avg. Loss: 4.0942
# Epoch [33/100], Avg. Loss: 4.0852
# Epoch [34/100], Avg. Loss: 4.0780
# Epoch [35/100], Avg. Loss: 4.0702
# Epoch [36/100], Avg. Loss: 4.0630
# Epoch [37/100], Avg. Loss: 4.0572
# Epoch [38/100], Avg. Loss: 4.0486
# Epoch [39/100], Avg. Loss: 4.0425
# Epoch [40/100], Avg. Loss: 4.0357
# Epoch [41/100], Avg. Loss: 4.0291
# Epoch [42/100], Avg. Loss: 4.0234
# Epoch [43/100], Avg. Loss: 4.0173
# Epoch [44/100], Avg. Loss: 4.0111
# Epoch [45/100], Avg. Loss: 4.0058
# Epoch [46/100], Avg. Loss: 3.9977
# Epoch [47/100], Avg. Loss: 3.9928
# Epoch [48/100], Avg. Loss: 3.9889
# Epoch [49/100], Avg. Loss: 3.9824
# Epoch [50/100], Avg. Loss: 3.9759
# Epoch [51/100], Avg. Loss: 3.9714
# Epoch [52/100], Avg. Loss: 3.9651
# Epoch [53/100], Avg. Loss: 3.9607
# Epoch [54/100], Avg. Loss: 3.9549
# Epoch [55/100], Avg. Loss: 3.9500
# Epoch [56/100], Avg. Loss: 3.9460
# Epoch [57/100], Avg. Loss: 3.9413
# Epoch [58/100], Avg. Loss: 3.9370
# Epoch [59/100], Avg. Loss: 3.9315
# Epoch [60/100], Avg. Loss: 3.9282
# Epoch [61/100], Avg. Loss: 3.9247
# Epoch [62/100], Avg. Loss: 3.9202
# Epoch [63/100], Avg. Loss: 3.9152
# Epoch [64/100], Avg. Loss: 3.9114
# Epoch [65/100], Avg. Loss: 3.9058
# Epoch [66/100], Avg. Loss: 3.9036
# Epoch [67/100], Avg. Loss: 3.8986
# Epoch [68/100], Avg. Loss: 3.8948
# Epoch [69/100], Avg. Loss: 3.8911
# Epoch [70/100], Avg. Loss: 3.8849
# Epoch [71/100], Avg. Loss: 3.8839
# Epoch [72/100], Avg. Loss: 3.8785
# Epoch [73/100], Avg. Loss: 3.8756
# Epoch [74/100], Avg. Loss: 3.8733
# Epoch [75/100], Avg. Loss: 3.8659
# Epoch [76/100], Avg. Loss: 3.8649
# Epoch [77/100], Avg. Loss: 3.8597
# Epoch [78/100], Avg. Loss: 3.8569
# Epoch [79/100], Avg. Loss: 3.8525
# Epoch [80/100], Avg. Loss: 3.8498
# Epoch [81/100], Avg. Loss: 3.8449
# Epoch [82/100], Avg. Loss: 3.8415
# Epoch [83/100], Avg. Loss: 3.8356
# Epoch [84/100], Avg. Loss: 3.8331
# Epoch [85/100], Avg. Loss: 3.8297
# Epoch [86/100], Avg. Loss: 3.8263
# Epoch [87/100], Avg. Loss: 3.8215
# Epoch [88/100], Avg. Loss: 3.8185
# Epoch [89/100], Avg. Loss: 3.8157
# Epoch [90/100], Avg. Loss: 3.8133
# Epoch [91/100], Avg. Loss: 3.8084
# Epoch [92/100], Avg. Loss: 3.8076
# Epoch [93/100], Avg. Loss: 3.8033
# Epoch [94/100], Avg. Loss: 3.8000
# Epoch [95/100], Avg. Loss: 3.7971
# Epoch [96/100], Avg. Loss: 3.7926
# Epoch [97/100], Avg. Loss: 3.7917
# Epoch [98/100], Avg. Loss: 3.7880
# Epoch [99/100], Avg. Loss: 3.7857
# Epoch [100/100], Avg. Loss: 3.7822
# Epoch [1/100], Avg. Loss: 35.4844
# Epoch [2/100], Avg. Loss: 5.5752
# Epoch [3/100], Avg. Loss: 4.9000
# Epoch [4/100], Avg. Loss: 4.7144
# Epoch [5/100], Avg. Loss: 4.6199
# Epoch [6/100], Avg. Loss: 4.5518
# Epoch [7/100], Avg. Loss: 4.4955
# Epoch [8/100], Avg. Loss: 4.4487
# Epoch [9/100], Avg. Loss: 4.4047
# Epoch [10/100], Avg. Loss: 4.3685
# Epoch [11/100], Avg. Loss: 4.3368
# Epoch [12/100], Avg. Loss: 4.3065
# Epoch [13/100], Avg. Loss: 4.2801
# Epoch [14/100], Avg. Loss: 4.2563
# Epoch [15/100], Avg. Loss: 4.2356
# Epoch [16/100], Avg. Loss: 4.2142
# Epoch [17/100], Avg. Loss: 4.1956
# Epoch [18/100], Avg. Loss: 4.1793
# Epoch [19/100], Avg. Loss: 4.1637
# Epoch [20/100], Avg. Loss: 4.1479
# Epoch [21/100], Avg. Loss: 4.1336
# Epoch [22/100], Avg. Loss: 4.1214
# Epoch [23/100], Avg. Loss: 4.1082
# Epoch [24/100], Avg. Loss: 4.0961
# Epoch [25/100], Avg. Loss: 4.0837
# Epoch [26/100], Avg. Loss: 4.0725
# Epoch [27/100], Avg. Loss: 4.0621
# Epoch [28/100], Avg. Loss: 4.0510
# Epoch [29/100], Avg. Loss: 4.0413
# Epoch [30/100], Avg. Loss: 4.0322
# Epoch [31/100], Avg. Loss: 4.0245
# Epoch [32/100], Avg. Loss: 4.0144
# Epoch [33/100], Avg. Loss: 4.0064
# Epoch [34/100], Avg. Loss: 3.9969
# Epoch [35/100], Avg. Loss: 3.9894
# Epoch [36/100], Avg. Loss: 3.9791
# Epoch [37/100], Avg. Loss: 3.9711
# Epoch [38/100], Avg. Loss: 3.9637
# Epoch [39/100], Avg. Loss: 3.9551
# Epoch [40/100], Avg. Loss: 3.9459
# Epoch [41/100], Avg. Loss: 3.9365
# Epoch [42/100], Avg. Loss: 3.9285
# Epoch [43/100], Avg. Loss: 3.9220
# Epoch [44/100], Avg. Loss: 3.9146
# Epoch [45/100], Avg. Loss: 3.9080
# Epoch [46/100], Avg. Loss: 3.9009
# Epoch [47/100], Avg. Loss: 3.8955
# Epoch [48/100], Avg. Loss: 3.8895
# Epoch [49/100], Avg. Loss: 3.8826
# Epoch [50/100], Avg. Loss: 3.8761
# Epoch [51/100], Avg. Loss: 3.8711
# Epoch [52/100], Avg. Loss: 3.8650
# Epoch [53/100], Avg. Loss: 3.8589
# Epoch [54/100], Avg. Loss: 3.8546
# Epoch [55/100], Avg. Loss: 3.8472
# Epoch [56/100], Avg. Loss: 3.8435
# Epoch [57/100], Avg. Loss: 3.8370
# Epoch [58/100], Avg. Loss: 3.8326
# Epoch [59/100], Avg. Loss: 3.8271
# Epoch [60/100], Avg. Loss: 3.8224
# Epoch [61/100], Avg. Loss: 3.8130
# Epoch [62/100], Avg. Loss: 3.8101
# Epoch [63/100], Avg. Loss: 3.8046
# Epoch [64/100], Avg. Loss: 3.7994
# Epoch [65/100], Avg. Loss: 3.7916
# Epoch [66/100], Avg. Loss: 3.7886
# Epoch [67/100], Avg. Loss: 3.7814
# Epoch [68/100], Avg. Loss: 3.7777
# Epoch [69/100], Avg. Loss: 3.7710
# Epoch [70/100], Avg. Loss: 3.7665
# Epoch [71/100], Avg. Loss: 3.7607
# Epoch [72/100], Avg. Loss: 3.7545
# Epoch [73/100], Avg. Loss: 3.7504
# Epoch [74/100], Avg. Loss: 3.7461
# Epoch [75/100], Avg. Loss: 3.7405
# Epoch [76/100], Avg. Loss: 3.7368
# Epoch [77/100], Avg. Loss: 3.7311
# Epoch [78/100], Avg. Loss: 3.7248
# Epoch [79/100], Avg. Loss: 3.7210
# Epoch [80/100], Avg. Loss: 3.7149
# Epoch [81/100], Avg. Loss: 3.7095
# Epoch [82/100], Avg. Loss: 3.7045
# Epoch [83/100], Avg. Loss: 3.7003
# Epoch [84/100], Avg. Loss: 3.6956
# Epoch [85/100], Avg. Loss: 3.6914
# Epoch [86/100], Avg. Loss: 3.6855
# Epoch [87/100], Avg. Loss: 3.6818
# Epoch [88/100], Avg. Loss: 3.6770
# Epoch [89/100], Avg. Loss: 3.6719
# Epoch [90/100], Avg. Loss: 3.6667
# Epoch [91/100], Avg. Loss: 3.6618
# Epoch [92/100], Avg. Loss: 3.6576
# Epoch [93/100], Avg. Loss: 3.6521
# Epoch [94/100], Avg. Loss: 3.6497
# Epoch [95/100], Avg. Loss: 3.6439
# Epoch [96/100], Avg. Loss: 3.6399
# Epoch [97/100], Avg. Loss: 3.6325
# Epoch [98/100], Avg. Loss: 3.6282
# Epoch [99/100], Avg. Loss: 3.6243
# Epoch [100/100], Avg. Loss: 3.6194
# Epoch [1/100], Avg. Loss: 40.4153
# Epoch [2/100], Avg. Loss: 7.4264
# Epoch [3/100], Avg. Loss: 5.7289
# Epoch [4/100], Avg. Loss: 5.2313
# Epoch [5/100], Avg. Loss: 4.9964
# Epoch [6/100], Avg. Loss: 4.8544
# Epoch [7/100], Avg. Loss: 4.7622
# Epoch [8/100], Avg. Loss: 4.6958
# Epoch [9/100], Avg. Loss: 4.6465
# Epoch [10/100], Avg. Loss: 4.6060
# Epoch [11/100], Avg. Loss: 4.5730
# Epoch [12/100], Avg. Loss: 4.5489
# Epoch [13/100], Avg. Loss: 4.5272
# Epoch [14/100], Avg. Loss: 4.5056
# Epoch [15/100], Avg. Loss: 4.4881
# Epoch [16/100], Avg. Loss: 4.4699
# Epoch [17/100], Avg. Loss: 4.4549
# Epoch [18/100], Avg. Loss: 4.4395
# Epoch [19/100], Avg. Loss: 4.4263
# Epoch [20/100], Avg. Loss: 4.4136
# Epoch [21/100], Avg. Loss: 4.4009
# Epoch [22/100], Avg. Loss: 4.3902
# Epoch [23/100], Avg. Loss: 4.3788
# Epoch [24/100], Avg. Loss: 4.3682
# Epoch [25/100], Avg. Loss: 4.3583
# Epoch [26/100], Avg. Loss: 4.3475
# Epoch [27/100], Avg. Loss: 4.3387
# Epoch [28/100], Avg. Loss: 4.3294
# Epoch [29/100], Avg. Loss: 4.3213
# Epoch [30/100], Avg. Loss: 4.3131
# Epoch [31/100], Avg. Loss: 4.3053
# Epoch [32/100], Avg. Loss: 4.2978
# Epoch [33/100], Avg. Loss: 4.2906
# Epoch [34/100], Avg. Loss: 4.2839
# Epoch [35/100], Avg. Loss: 4.2767
# Epoch [36/100], Avg. Loss: 4.2706
# Epoch [37/100], Avg. Loss: 4.2643
# Epoch [38/100], Avg. Loss: 4.2584
# Epoch [39/100], Avg. Loss: 4.2526
# Epoch [40/100], Avg. Loss: 4.2473
# Epoch [41/100], Avg. Loss: 4.2418
# Epoch [42/100], Avg. Loss: 4.2363
# Epoch [43/100], Avg. Loss: 4.2314
# Epoch [44/100], Avg. Loss: 4.2259
# Epoch [45/100], Avg. Loss: 4.2213
# Epoch [46/100], Avg. Loss: 4.2162
# Epoch [47/100], Avg. Loss: 4.2123
# Epoch [48/100], Avg. Loss: 4.2077
# Epoch [49/100], Avg. Loss: 4.2030
# Epoch [50/100], Avg. Loss: 4.1985
# Epoch [51/100], Avg. Loss: 4.1942
# Epoch [52/100], Avg. Loss: 4.1900
# Epoch [53/100], Avg. Loss: 4.1859
# Epoch [54/100], Avg. Loss: 4.1817
# Epoch [55/100], Avg. Loss: 4.1777
# Epoch [56/100], Avg. Loss: 4.1738
# Epoch [57/100], Avg. Loss: 4.1704
# Epoch [58/100], Avg. Loss: 4.1669
# Epoch [59/100], Avg. Loss: 4.1635
# Epoch [60/100], Avg. Loss: 4.1607
# Epoch [61/100], Avg. Loss: 4.1575
# Epoch [62/100], Avg. Loss: 4.1543
# Epoch [63/100], Avg. Loss: 4.1513
# Epoch [64/100], Avg. Loss: 4.1481
# Epoch [65/100], Avg. Loss: 4.1455
# Epoch [66/100], Avg. Loss: 4.1426
# Epoch [67/100], Avg. Loss: 4.1403
# Epoch [68/100], Avg. Loss: 4.1376
# Epoch [69/100], Avg. Loss: 4.1350
# Epoch [70/100], Avg. Loss: 4.1324
# Epoch [71/100], Avg. Loss: 4.1300
# Epoch [72/100], Avg. Loss: 4.1276
# Epoch [73/100], Avg. Loss: 4.1253
# Epoch [74/100], Avg. Loss: 4.1233
# Epoch [75/100], Avg. Loss: 4.1210
# Epoch [76/100], Avg. Loss: 4.1189
# Epoch [77/100], Avg. Loss: 4.1170
# Epoch [78/100], Avg. Loss: 4.1152
# Epoch [79/100], Avg. Loss: 4.1133
# Epoch [80/100], Avg. Loss: 4.1115
# Epoch [81/100], Avg. Loss: 4.1098
# Epoch [82/100], Avg. Loss: 4.1079
# Epoch [83/100], Avg. Loss: 4.1060
# Epoch [84/100], Avg. Loss: 4.1041
# Epoch [85/100], Avg. Loss: 4.1022
# Epoch [86/100], Avg. Loss: 4.1005
# Epoch [87/100], Avg. Loss: 4.0987
# Epoch [88/100], Avg. Loss: 4.0972
# Epoch [89/100], Avg. Loss: 4.0955
# Epoch [90/100], Avg. Loss: 4.0940
# Epoch [91/100], Avg. Loss: 4.0925
# Epoch [92/100], Avg. Loss: 4.0911
# Epoch [93/100], Avg. Loss: 4.0894
# Epoch [94/100], Avg. Loss: 4.0882
# Epoch [95/100], Avg. Loss: 4.0868
# Epoch [96/100], Avg. Loss: 4.0853
# Epoch [97/100], Avg. Loss: 4.0841
# Epoch [98/100], Avg. Loss: 4.0827
# Epoch [99/100], Avg. Loss: 4.0812
# Epoch [100/100], Avg. Loss: 4.0795
# Epoch [1/100], Avg. Loss: 48.2520
# Epoch [2/100], Avg. Loss: 6.6192
# Epoch [3/100], Avg. Loss: 5.6612
# Epoch [4/100], Avg. Loss: 5.3004
# Epoch [5/100], Avg. Loss: 5.0838
# Epoch [6/100], Avg. Loss: 4.9430
# Epoch [7/100], Avg. Loss: 4.8455
# Epoch [8/100], Avg. Loss: 4.7773
# Epoch [9/100], Avg. Loss: 4.7161
# Epoch [10/100], Avg. Loss: 4.6685
# Epoch [11/100], Avg. Loss: 4.6286
# Epoch [12/100], Avg. Loss: 4.5904
# Epoch [13/100], Avg. Loss: 4.5575
# Epoch [14/100], Avg. Loss: 4.5274
# Epoch [15/100], Avg. Loss: 4.5011
# Epoch [16/100], Avg. Loss: 4.4794
# Epoch [17/100], Avg. Loss: 4.4592
# Epoch [18/100], Avg. Loss: 4.4402
# Epoch [19/100], Avg. Loss: 4.4229
# Epoch [20/100], Avg. Loss: 4.4056
# Epoch [21/100], Avg. Loss: 4.3899
# Epoch [22/100], Avg. Loss: 4.3760
# Epoch [23/100], Avg. Loss: 4.3624
# Epoch [24/100], Avg. Loss: 4.3496
# Epoch [25/100], Avg. Loss: 4.3377
# Epoch [26/100], Avg. Loss: 4.3258
# Epoch [27/100], Avg. Loss: 4.3151
# Epoch [28/100], Avg. Loss: 4.3037
# Epoch [29/100], Avg. Loss: 4.2932
# Epoch [30/100], Avg. Loss: 4.2831
# Epoch [31/100], Avg. Loss: 4.2730
# Epoch [32/100], Avg. Loss: 4.2631
# Epoch [33/100], Avg. Loss: 4.2531
# Epoch [34/100], Avg. Loss: 4.2445
# Epoch [35/100], Avg. Loss: 4.2360
# Epoch [36/100], Avg. Loss: 4.2284
# Epoch [37/100], Avg. Loss: 4.2209
# Epoch [38/100], Avg. Loss: 4.2139
# Epoch [39/100], Avg. Loss: 4.2063
# Epoch [40/100], Avg. Loss: 4.1994
# Epoch [41/100], Avg. Loss: 4.1926
# Epoch [42/100], Avg. Loss: 4.1863
# Epoch [43/100], Avg. Loss: 4.1804
# Epoch [44/100], Avg. Loss: 4.1749
# Epoch [45/100], Avg. Loss: 4.1688
# Epoch [46/100], Avg. Loss: 4.1632
# Epoch [47/100], Avg. Loss: 4.1577
# Epoch [48/100], Avg. Loss: 4.1523
# Epoch [49/100], Avg. Loss: 4.1472
# Epoch [50/100], Avg. Loss: 4.1422
# Epoch [51/100], Avg. Loss: 4.1376
# Epoch [52/100], Avg. Loss: 4.1319
# Epoch [53/100], Avg. Loss: 4.1276
# Epoch [54/100], Avg. Loss: 4.1234
# Epoch [55/100], Avg. Loss: 4.1188
# Epoch [56/100], Avg. Loss: 4.1142
# Epoch [57/100], Avg. Loss: 4.1099
# Epoch [58/100], Avg. Loss: 4.1057
# Epoch [59/100], Avg. Loss: 4.1021
# Epoch [60/100], Avg. Loss: 4.0988
# Epoch [61/100], Avg. Loss: 4.0956
# Epoch [62/100], Avg. Loss: 4.0924
# Epoch [63/100], Avg. Loss: 4.0896
# Epoch [64/100], Avg. Loss: 4.0868
# Epoch [65/100], Avg. Loss: 4.0839
# Epoch [66/100], Avg. Loss: 4.0814
# Epoch [67/100], Avg. Loss: 4.0789
# Epoch [68/100], Avg. Loss: 4.0765
# Epoch [69/100], Avg. Loss: 4.0741
# Epoch [70/100], Avg. Loss: 4.0718
# Epoch [71/100], Avg. Loss: 4.0698
# Epoch [72/100], Avg. Loss: 4.0673
# Epoch [73/100], Avg. Loss: 4.0649
# Epoch [74/100], Avg. Loss: 4.0627
# Epoch [75/100], Avg. Loss: 4.0606
# Epoch [76/100], Avg. Loss: 4.0586
# Epoch [77/100], Avg. Loss: 4.0567
# Epoch [78/100], Avg. Loss: 4.0547
# Epoch [79/100], Avg. Loss: 4.0527
# Epoch [80/100], Avg. Loss: 4.0509
# Epoch [81/100], Avg. Loss: 4.0492
# Epoch [82/100], Avg. Loss: 4.0476
# Epoch [83/100], Avg. Loss: 4.0456
# Epoch [84/100], Avg. Loss: 4.0440
# Epoch [85/100], Avg. Loss: 4.0423
# Epoch [86/100], Avg. Loss: 4.0405
# Epoch [87/100], Avg. Loss: 4.0389
# Epoch [88/100], Avg. Loss: 4.0374
# Epoch [89/100], Avg. Loss: 4.0355
# Epoch [90/100], Avg. Loss: 4.0341
# Epoch [91/100], Avg. Loss: 4.0323
# Epoch [92/100], Avg. Loss: 4.0300
# Epoch [93/100], Avg. Loss: 4.0280
# Epoch [94/100], Avg. Loss: 4.0263
# Epoch [95/100], Avg. Loss: 4.0241
# Epoch [96/100], Avg. Loss: 4.0220
# Epoch [97/100], Avg. Loss: 4.0207
# Epoch [98/100], Avg. Loss: 4.0189
# Epoch [99/100], Avg. Loss: 4.0173
# Epoch [100/100], Avg. Loss: 4.0153
# Epoch [1/100], Avg. Loss: 66.0060
# Epoch [2/100], Avg. Loss: 7.9158
# Epoch [3/100], Avg. Loss: 6.1085
# Epoch [4/100], Avg. Loss: 5.4878
# Epoch [5/100], Avg. Loss: 5.1314
# Epoch [6/100], Avg. Loss: 4.8815
# Epoch [7/100], Avg. Loss: 4.7226
# Epoch [8/100], Avg. Loss: 4.6319
# Epoch [9/100], Avg. Loss: 4.5769
# Epoch [10/100], Avg. Loss: 4.5296
# Epoch [11/100], Avg. Loss: 4.4960
# Epoch [12/100], Avg. Loss: 4.4695
# Epoch [13/100], Avg. Loss: 4.4469
# Epoch [14/100], Avg. Loss: 4.4287
# ...
# Epoch [86/100], Avg. Loss: nan
# Epoch [87/100], Avg. Loss: nan
# Epoch [88/100], Avg. Loss: nan
# Epoch [89/100], Avg. Loss: nan
# Epoch [90/100], Avg. Loss: nan
# Epoch [91/100], Avg. Loss: nan
# Epoch [92/100], Avg. Loss: nan
# Epoch [93/100], Avg. Loss: nan
# Epoch [94/100], Avg. Loss: nan
# Epoch [95/100], Avg. Loss: nan
# Epoch [96/100], Avg. Loss: nan
# Epoch [97/100], Avg. Loss: nan
# Epoch [98/100], Avg. Loss: nan
# Epoch [99/100], Avg. Loss: nan
# Epoch [100/100], Avg. Loss: nan
# Epoch [1/100], Avg. Loss: nan
# Epoch [2/100], Avg. Loss: nan
# Epoch [3/100], Avg. Loss: nan
# Epoch [4/100], Avg. Loss: nan
# Epoch [5/100], Avg. Loss: nan
# Epoch [6/100], Avg. Loss: nan
# Epoch [7/100], Avg. Loss: nan
# Epoch [8/100], Avg. Loss: nan
# Epoch [9/100], Avg. Loss: nan
# Epoch [10/100], Avg. Loss: nan
# Epoch [11/100], Avg. Loss: nan
# Epoch [12/100], Avg. Loss: nan
# Epoch [13/100], Avg. Loss: nan
# Epoch [14/100], Avg. Loss: nan
# Epoch [15/100], Avg. Loss: nan
# Epoch [16/100], Avg. Loss: nan
# Epoch [17/100], Avg. Loss: nan
# Epoch [18/100], Avg. Loss: nan
# Epoch [19/100], Avg. Loss: nan
# Epoch [20/100], Avg. Loss: nan
# Epoch [21/100], Avg. Loss: nan
# Epoch [22/100], Avg. Loss: nan
# Epoch [23/100], Avg. Loss: nan
# Epoch [24/100], Avg. Loss: nan
# Epoch [25/100], Avg. Loss: nan
# Epoch [26/100], Avg. Loss: nan
# Epoch [27/100], Avg. Loss: nan
# Epoch [28/100], Avg. Loss: nan
# Epoch [29/100], Avg. Loss: nan
# Epoch [30/100], Avg. Loss: nan
# Epoch [31/100], Avg. Loss: nan
# Epoch [32/100], Avg. Loss: nan
# Epoch [33/100], Avg. Loss: nan
# Epoch [34/100], Avg. Loss: nan
# Epoch [35/100], Avg. Loss: nan
# Epoch [36/100], Avg. Loss: nan
# Epoch [37/100], Avg. Loss: nan
# Epoch [38/100], Avg. Loss: nan
# Epoch [39/100], Avg. Loss: nan
# Epoch [40/100], Avg. Loss: nan
# Epoch [41/100], Avg. Loss: nan
# Epoch [42/100], Avg. Loss: nan
# Epoch [43/100], Avg. Loss: nan
# Epoch [44/100], Avg. Loss: nan
# Epoch [45/100], Avg. Loss: nan
# Epoch [46/100], Avg. Loss: nan
# Epoch [47/100], Avg. Loss: nan
# Epoch [48/100], Avg. Loss: nan
# Epoch [49/100], Avg. Loss: nan
# Epoch [50/100], Avg. Loss: nan
# Epoch [51/100], Avg. Loss: nan
# Epoch [52/100], Avg. Loss: nan
# Epoch [53/100], Avg. Loss: nan
# Epoch [54/100], Avg. Loss: nan
# Epoch [55/100], Avg. Loss: nan
# Epoch [56/100], Avg. Loss: nan
# Epoch [57/100], Avg. Loss: nan
# Epoch [58/100], Avg. Loss: nan
# Epoch [59/100], Avg. Loss: nan
# Epoch [60/100], Avg. Loss: nan
# Epoch [61/100], Avg. Loss: nan
# Epoch [62/100], Avg. Loss: nan
# Epoch [63/100], Avg. Loss: nan
# Epoch [64/100], Avg. Loss: nan
# Epoch [65/100], Avg. Loss: nan
# Epoch [66/100], Avg. Loss: nan
# Epoch [67/100], Avg. Loss: nan
# Epoch [68/100], Avg. Loss: nan
# Epoch [69/100], Avg. Loss: nan
# Epoch [70/100], Avg. Loss: nan
# Epoch [71/100], Avg. Loss: nan
# Epoch [72/100], Avg. Loss: nan
# Epoch [73/100], Avg. Loss: nan
# Epoch [74/100], Avg. Loss: nan
# Epoch [75/100], Avg. Loss: nan
# Epoch [76/100], Avg. Loss: nan
# Epoch [77/100], Avg. Loss: nan
# Epoch [78/100], Avg. Loss: nan
# Epoch [79/100], Avg. Loss: nan
# Epoch [80/100], Avg. Loss: nan
# Epoch [81/100], Avg. Loss: nan
# Epoch [82/100], Avg. Loss: nan
# Epoch [83/100], Avg. Loss: nan
# Epoch [84/100], Avg. Loss: nan
# Epoch [85/100], Avg. Loss: nan
# Epoch [86/100], Avg. Loss: nan
# Epoch [87/100], Avg. Loss: nan
# Epoch [88/100], Avg. Loss: nan
# Epoch [89/100], Avg. Loss: nan
# Epoch [90/100], Avg. Loss: nan
# Epoch [91/100], Avg. Loss: nan
# Epoch [92/100], Avg. Loss: nan
# Epoch [93/100], Avg. Loss: nan
# Epoch [94/100], Avg. Loss: nan
# Epoch [95/100], Avg. Loss: nan
# Epoch [96/100], Avg. Loss: nan
# Epoch [97/100], Avg. Loss: nan
# Epoch [98/100], Avg. Loss: nan
# Epoch [99/100], Avg. Loss: nan
# Epoch [100/100], Avg. Loss: nan
# Epoch [1/100], Avg. Loss: 33.8092
# Epoch [2/100], Avg. Loss: 8.1473
# Epoch [3/100], Avg. Loss: 7.2527
# Epoch [4/100], Avg. Loss: 6.7876
# Epoch [5/100], Avg. Loss: 6.6266
# Epoch [6/100], Avg. Loss: 6.3581
# Epoch [7/100], Avg. Loss: 6.3818
# Epoch [8/100], Avg. Loss: 6.4430
# Epoch [9/100], Avg. Loss: 6.3176
# Epoch [10/100], Avg. Loss: nan
# Epoch [11/100], Avg. Loss: nan
# Epoch [12/100], Avg. Loss: nan
# Epoch [13/100], Avg. Loss: nan
# Epoch [14/100], Avg. Loss: nan
# Epoch [15/100], Avg. Loss: nan
# Epoch [16/100], Avg. Loss: nan
# Epoch [17/100], Avg. Loss: nan
# Epoch [18/100], Avg. Loss: nan
# Epoch [19/100], Avg. Loss: nan
# Epoch [20/100], Avg. Loss: nan
# Epoch [21/100], Avg. Loss: nan
# Epoch [22/100], Avg. Loss: nan
# Epoch [23/100], Avg. Loss: nan
# Epoch [24/100], Avg. Loss: nan
# Epoch [25/100], Avg. Loss: nan
# Epoch [26/100], Avg. Loss: nan
# Epoch [27/100], Avg. Loss: nan
# Epoch [28/100], Avg. Loss: nan
# Epoch [29/100], Avg. Loss: nan
# Epoch [30/100], Avg. Loss: nan
# Epoch [31/100], Avg. Loss: nan
# Epoch [32/100], Avg. Loss: nan
# Epoch [33/100], Avg. Loss: nan
# Epoch [34/100], Avg. Loss: nan
# Epoch [35/100], Avg. Loss: nan
# Epoch [36/100], Avg. Loss: nan
# Epoch [37/100], Avg. Loss: nan
# Epoch [38/100], Avg. Loss: nan
# Epoch [39/100], Avg. Loss: nan
# Epoch [40/100], Avg. Loss: nan
# Epoch [41/100], Avg. Loss: nan
# Epoch [42/100], Avg. Loss: nan
# Epoch [43/100], Avg. Loss: nan
# Epoch [44/100], Avg. Loss: nan
# Epoch [45/100], Avg. Loss: nan
# Epoch [46/100], Avg. Loss: nan
# Epoch [47/100], Avg. Loss: nan
# Epoch [48/100], Avg. Loss: nan
# Epoch [49/100], Avg. Loss: nan
# Epoch [50/100], Avg. Loss: nan
# Epoch [51/100], Avg. Loss: nan
# Epoch [52/100], Avg. Loss: nan
# Epoch [53/100], Avg. Loss: nan
# Epoch [54/100], Avg. Loss: nan
# Epoch [55/100], Avg. Loss: nan
# Epoch [56/100], Avg. Loss: nan
# Epoch [57/100], Avg. Loss: nan
# Epoch [58/100], Avg. Loss: nan
# Epoch [59/100], Avg. Loss: nan
# Epoch [60/100], Avg. Loss: nan
# Epoch [61/100], Avg. Loss: nan
# Epoch [62/100], Avg. Loss: nan
# Epoch [63/100], Avg. Loss: nan
# Epoch [64/100], Avg. Loss: nan
# Epoch [65/100], Avg. Loss: nan
# Epoch [66/100], Avg. Loss: nan
# Epoch [67/100], Avg. Loss: nan
# Epoch [68/100], Avg. Loss: nan
# Epoch [69/100], Avg. Loss: nan
# Epoch [70/100], Avg. Loss: nan
# Epoch [71/100], Avg. Loss: nan
# Epoch [72/100], Avg. Loss: nan
# Epoch [73/100], Avg. Loss: nan
# Epoch [74/100], Avg. Loss: nan
# Epoch [75/100], Avg. Loss: nan
# Epoch [76/100], Avg. Loss: nan
# Epoch [77/100], Avg. Loss: nan
# Epoch [78/100], Avg. Loss: nan
# Epoch [79/100], Avg. Loss: nan
# Epoch [80/100], Avg. Loss: nan
# Epoch [81/100], Avg. Loss: nan
# Epoch [82/100], Avg. Loss: nan
# Epoch [83/100], Avg. Loss: nan
# Epoch [84/100], Avg. Loss: nan
# Epoch [85/100], Avg. Loss: nan
# Epoch [86/100], Avg. Loss: nan
# Epoch [87/100], Avg. Loss: nan
# Epoch [88/100], Avg. Loss: nan
# Epoch [89/100], Avg. Loss: nan
# Epoch [90/100], Avg. Loss: nan
# Epoch [91/100], Avg. Loss: nan
# Epoch [92/100], Avg. Loss: nan
# Epoch [93/100], Avg. Loss: nan
# Epoch [94/100], Avg. Loss: nan
# Epoch [95/100], Avg. Loss: nan
# Epoch [96/100], Avg. Loss: nan
# Epoch [97/100], Avg. Loss: nan
# Epoch [98/100], Avg. Loss: nan
# Epoch [99/100], Avg. Loss: nan
# Epoch [100/100], Avg. Loss: nan
# Epoch [1/100], Avg. Loss: nan
# Epoch [2/100], Avg. Loss: nan
# Epoch [3/100], Avg. Loss: nan
# Epoch [4/100], Avg. Loss: nan
# Epoch [5/100], Avg. Loss: nan
# Epoch [6/100], Avg. Loss: nan
# Epoch [7/100], Avg. Loss: nan
# Epoch [8/100], Avg. Loss: nan
# Epoch [9/100], Avg. Loss: nan
# Epoch [10/100], Avg. Loss: nan
# Epoch [11/100], Avg. Loss: nan
# Epoch [12/100], Avg. Loss: nan
# Epoch [13/100], Avg. Loss: nan
# Epoch [14/100], Avg. Loss: nan
# Epoch [15/100], Avg. Loss: nan
# Epoch [16/100], Avg. Loss: nan
# Epoch [17/100], Avg. Loss: nan
# Epoch [18/100], Avg. Loss: nan
# Epoch [19/100], Avg. Loss: nan
# Epoch [20/100], Avg. Loss: nan
# Epoch [21/100], Avg. Loss: nan
# Epoch [22/100], Avg. Loss: nan
# Epoch [23/100], Avg. Loss: nan
# Epoch [24/100], Avg. Loss: nan
# Epoch [25/100], Avg. Loss: nan
# Epoch [26/100], Avg. Loss: nan
# Epoch [27/100], Avg. Loss: nan
# Epoch [28/100], Avg. Loss: nan
# Epoch [29/100], Avg. Loss: nan
# Epoch [30/100], Avg. Loss: nan
# Epoch [31/100], Avg. Loss: nan
# Epoch [32/100], Avg. Loss: nan
# Epoch [33/100], Avg. Loss: nan
# Epoch [34/100], Avg. Loss: nan
# Epoch [35/100], Avg. Loss: nan
# Epoch [36/100], Avg. Loss: nan
# Epoch [37/100], Avg. Loss: nan
# Epoch [38/100], Avg. Loss: nan
# Epoch [39/100], Avg. Loss: nan
# Epoch [40/100], Avg. Loss: nan
# Epoch [41/100], Avg. Loss: nan
# Epoch [42/100], Avg. Loss: nan
# Epoch [43/100], Avg. Loss: nan
# Epoch [44/100], Avg. Loss: nan
# Epoch [45/100], Avg. Loss: nan
# Epoch [46/100], Avg. Loss: nan
# Epoch [47/100], Avg. Loss: nan
# Epoch [48/100], Avg. Loss: nan
# Epoch [49/100], Avg. Loss: nan
# Epoch [50/100], Avg. Loss: nan
# Epoch [51/100], Avg. Loss: nan
# Epoch [52/100], Avg. Loss: nan
# Epoch [53/100], Avg. Loss: nan
# Epoch [54/100], Avg. Loss: nan
# Epoch [55/100], Avg. Loss: nan
# Epoch [56/100], Avg. Loss: nan
# Epoch [57/100], Avg. Loss: nan
# Epoch [58/100], Avg. Loss: nan
# Epoch [59/100], Avg. Loss: nan
# Epoch [60/100], Avg. Loss: nan
# Epoch [61/100], Avg. Loss: nan
# Epoch [62/100], Avg. Loss: nan
# Epoch [63/100], Avg. Loss: nan
# Epoch [64/100], Avg. Loss: nan
# Epoch [65/100], Avg. Loss: nan
# Epoch [66/100], Avg. Loss: nan
# Epoch [67/100], Avg. Loss: nan
# Epoch [68/100], Avg. Loss: nan
# Epoch [69/100], Avg. Loss: nan
# Epoch [70/100], Avg. Loss: nan
# Epoch [71/100], Avg. Loss: nan
# Epoch [72/100], Avg. Loss: nan
# Epoch [73/100], Avg. Loss: nan
# Epoch [74/100], Avg. Loss: nan
# Epoch [75/100], Avg. Loss: nan
# Epoch [76/100], Avg. Loss: nan
# Epoch [77/100], Avg. Loss: nan
# Epoch [78/100], Avg. Loss: nan
# Epoch [79/100], Avg. Loss: nan
# Epoch [80/100], Avg. Loss: nan
# Epoch [81/100], Avg. Loss: nan
# Epoch [82/100], Avg. Loss: nan
# Epoch [83/100], Avg. Loss: nan
# Epoch [84/100], Avg. Loss: nan
# Epoch [85/100], Avg. Loss: nan
# Epoch [86/100], Avg. Loss: nan
# Epoch [87/100], Avg. Loss: nan
# Epoch [88/100], Avg. Loss: nan
# Epoch [89/100], Avg. Loss: nan
# Epoch [90/100], Avg. Loss: nan
# Epoch [91/100], Avg. Loss: nan
# Epoch [92/100], Avg. Loss: nan
# Epoch [93/100], Avg. Loss: nan
# Epoch [94/100], Avg. Loss: nan
# Epoch [95/100], Avg. Loss: nan
# Epoch [96/100], Avg. Loss: nan
# Epoch [97/100], Avg. Loss: nan
# Epoch [98/100], Avg. Loss: nan
# Epoch [99/100], Avg. Loss: nan
# Epoch [100/100], Avg. Loss: nan
# Epoch [1/100], Avg. Loss: nan
# Epoch [2/100], Avg. Loss: nan
# Epoch [3/100], Avg. Loss: nan
# Epoch [4/100], Avg. Loss: nan
# Epoch [5/100], Avg. Loss: nan
# Epoch [6/100], Avg. Loss: nan
# Epoch [7/100], Avg. Loss: nan
# Epoch [8/100], Avg. Loss: nan
# Epoch [9/100], Avg. Loss: nan
# Epoch [10/100], Avg. Loss: nan
# Epoch [11/100], Avg. Loss: nan
# Epoch [12/100], Avg. Loss: nan
# Epoch [13/100], Avg. Loss: nan
# Epoch [14/100], Avg. Loss: nan
# Epoch [15/100], Avg. Loss: nan
# Epoch [16/100], Avg. Loss: nan
# Epoch [17/100], Avg. Loss: nan
# Epoch [18/100], Avg. Loss: nan
# Epoch [19/100], Avg. Loss: nan
# Epoch [20/100], Avg. Loss: nan
# Epoch [21/100], Avg. Loss: nan
# Epoch [22/100], Avg. Loss: nan
# Epoch [23/100], Avg. Loss: nan
# Epoch [24/100], Avg. Loss: nan
# Epoch [25/100], Avg. Loss: nan
# Epoch [26/100], Avg. Loss: nan
# Epoch [27/100], Avg. Loss: nan
# Epoch [28/100], Avg. Loss: nan
# Epoch [29/100], Avg. Loss: nan
# Epoch [30/100], Avg. Loss: nan
# Epoch [31/100], Avg. Loss: nan
# Epoch [32/100], Avg. Loss: nan
# Epoch [33/100], Avg. Loss: nan
# Epoch [34/100], Avg. Loss: nan
# Epoch [35/100], Avg. Loss: nan
# Epoch [36/100], Avg. Loss: nan
# Epoch [37/100], Avg. Loss: nan
# Epoch [38/100], Avg. Loss: nan
# Epoch [39/100], Avg. Loss: nan
# Epoch [40/100], Avg. Loss: nan
# Epoch [41/100], Avg. Loss: nan
# Epoch [42/100], Avg. Loss: nan
# Epoch [43/100], Avg. Loss: nan
# Epoch [44/100], Avg. Loss: nan
# Epoch [45/100], Avg. Loss: nan
# Epoch [46/100], Avg. Loss: nan
# Epoch [47/100], Avg. Loss: nan
# Epoch [48/100], Avg. Loss: nan
# Epoch [49/100], Avg. Loss: nan
# Epoch [50/100], Avg. Loss: nan
# Epoch [51/100], Avg. Loss: nan
# Epoch [52/100], Avg. Loss: nan
# Epoch [53/100], Avg. Loss: nan
# Epoch [54/100], Avg. Loss: nan
# Epoch [55/100], Avg. Loss: nan
# Epoch [56/100], Avg. Loss: nan
# Epoch [57/100], Avg. Loss: nan
# Epoch [58/100], Avg. Loss: nan
# Epoch [59/100], Avg. Loss: nan
# Epoch [60/100], Avg. Loss: nan
# Epoch [61/100], Avg. Loss: nan
# Epoch [62/100], Avg. Loss: nan
# Epoch [63/100], Avg. Loss: nan
# Epoch [64/100], Avg. Loss: nan
# Epoch [65/100], Avg. Loss: nan
# Epoch [66/100], Avg. Loss: nan
# Epoch [67/100], Avg. Loss: nan
# Epoch [68/100], Avg. Loss: nan
# Epoch [69/100], Avg. Loss: nan
# Epoch [70/100], Avg. Loss: nan
# Epoch [71/100], Avg. Loss: nan
# Epoch [72/100], Avg. Loss: nan
# Epoch [73/100], Avg. Loss: nan
# Epoch [74/100], Avg. Loss: nan
# Epoch [75/100], Avg. Loss: nan
# Epoch [76/100], Avg. Loss: nan
# Epoch [77/100], Avg. Loss: nan
# Epoch [78/100], Avg. Loss: nan
# Epoch [79/100], Avg. Loss: nan
# Epoch [80/100], Avg. Loss: nan
# Epoch [81/100], Avg. Loss: nan
# Epoch [82/100], Avg. Loss: nan
# Epoch [83/100], Avg. Loss: nan
# Epoch [84/100], Avg. Loss: nan
# Epoch [85/100], Avg. Loss: nan
# Epoch [86/100], Avg. Loss: nan
# Epoch [87/100], Avg. Loss: nan
# Epoch [88/100], Avg. Loss: nan
# Epoch [89/100], Avg. Loss: nan
# Epoch [90/100], Avg. Loss: nan
# Epoch [91/100], Avg. Loss: nan
# Epoch [92/100], Avg. Loss: nan
# Epoch [93/100], Avg. Loss: nan
# Epoch [94/100], Avg. Loss: nan
# Epoch [95/100], Avg. Loss: nan
# Epoch [96/100], Avg. Loss: nan
# Epoch [97/100], Avg. Loss: nan
# Epoch [98/100], Avg. Loss: nan
# Epoch [99/100], Avg. Loss: nan
# Epoch [100/100], Avg. Loss: nan
# Epoch [1/100], Avg. Loss: 14.8425
# Epoch [2/100], Avg. Loss: 7.6727
# Epoch [3/100], Avg. Loss: 7.0093
# Epoch [4/100], Avg. Loss: 6.7498
# Epoch [5/100], Avg. Loss: 6.8690
# Epoch [6/100], Avg. Loss: 8.5063
# Epoch [7/100], Avg. Loss: 7.8247
# Epoch [8/100], Avg. Loss: 7.5685
# Epoch [9/100], Avg. Loss: 9.3236
# Epoch [10/100], Avg. Loss: nan
# Epoch [11/100], Avg. Loss: nan
# Epoch [12/100], Avg. Loss: nan
# Epoch [13/100], Avg. Loss: nan
# Epoch [14/100], Avg. Loss: nan
# Epoch [15/100], Avg. Loss: nan
# Epoch [16/100], Avg. Loss: nan
# Epoch [17/100], Avg. Loss: nan
# Epoch [18/100], Avg. Loss: nan
# Epoch [19/100], Avg. Loss: nan
# Epoch [20/100], Avg. Loss: nan
# Epoch [21/100], Avg. Loss: nan
# Epoch [22/100], Avg. Loss: nan
# Epoch [23/100], Avg. Loss: nan
# Epoch [24/100], Avg. Loss: nan
# Epoch [25/100], Avg. Loss: nan
# Epoch [26/100], Avg. Loss: nan
# Epoch [27/100], Avg. Loss: nan
# Epoch [28/100], Avg. Loss: nan
# Epoch [29/100], Avg. Loss: nan
# Epoch [30/100], Avg. Loss: nan
# Epoch [31/100], Avg. Loss: nan
# Epoch [32/100], Avg. Loss: nan
# Epoch [33/100], Avg. Loss: nan
# Epoch [34/100], Avg. Loss: nan
# Epoch [35/100], Avg. Loss: nan
# Epoch [36/100], Avg. Loss: nan
# Epoch [37/100], Avg. Loss: nan
# Epoch [38/100], Avg. Loss: nan
# Epoch [39/100], Avg. Loss: nan
# Epoch [40/100], Avg. Loss: nan
# Epoch [41/100], Avg. Loss: nan
# Epoch [42/100], Avg. Loss: nan
# Epoch [43/100], Avg. Loss: nan
# Epoch [44/100], Avg. Loss: nan
# Epoch [45/100], Avg. Loss: nan
# Epoch [46/100], Avg. Loss: nan
# Epoch [47/100], Avg. Loss: nan
# Epoch [48/100], Avg. Loss: nan
# Epoch [49/100], Avg. Loss: nan
# Epoch [50/100], Avg. Loss: nan
# Epoch [51/100], Avg. Loss: nan
# Epoch [52/100], Avg. Loss: nan
# Epoch [53/100], Avg. Loss: nan
# Epoch [54/100], Avg. Loss: nan
# Epoch [55/100], Avg. Loss: nan
# Epoch [56/100], Avg. Loss: nan
# Epoch [57/100], Avg. Loss: nan
# Epoch [58/100], Avg. Loss: nan
# Epoch [59/100], Avg. Loss: nan
# Epoch [60/100], Avg. Loss: nan
# Epoch [61/100], Avg. Loss: nan
# Epoch [62/100], Avg. Loss: nan
# Epoch [63/100], Avg. Loss: nan
# Epoch [64/100], Avg. Loss: nan
# Epoch [65/100], Avg. Loss: nan
# Epoch [66/100], Avg. Loss: nan
# Epoch [67/100], Avg. Loss: nan
# Epoch [68/100], Avg. Loss: nan
# Epoch [69/100], Avg. Loss: nan
# Epoch [70/100], Avg. Loss: nan
# Epoch [71/100], Avg. Loss: nan
# Epoch [72/100], Avg. Loss: nan
# Epoch [73/100], Avg. Loss: nan
# Epoch [74/100], Avg. Loss: nan
# Epoch [75/100], Avg. Loss: nan
# Epoch [76/100], Avg. Loss: nan
# Epoch [77/100], Avg. Loss: nan
# Epoch [78/100], Avg. Loss: nan
# Epoch [79/100], Avg. Loss: nan
# Epoch [80/100], Avg. Loss: nan
# Epoch [81/100], Avg. Loss: nan
# Epoch [82/100], Avg. Loss: nan
# Epoch [83/100], Avg. Loss: nan
# Epoch [84/100], Avg. Loss: nan
# Epoch [85/100], Avg. Loss: nan
# Epoch [86/100], Avg. Loss: nan
# Epoch [87/100], Avg. Loss: nan
# Epoch [88/100], Avg. Loss: nan
# Epoch [89/100], Avg. Loss: nan
# Epoch [90/100], Avg. Loss: nan
# Epoch [91/100], Avg. Loss: nan
# Epoch [92/100], Avg. Loss: nan
# Epoch [93/100], Avg. Loss: nan
# Epoch [94/100], Avg. Loss: nan
# Epoch [95/100], Avg. Loss: nan
# Epoch [96/100], Avg. Loss: nan
# Epoch [97/100], Avg. Loss: nan
# Epoch [98/100], Avg. Loss: nan
# Epoch [99/100], Avg. Loss: nan
# Epoch [100/100], Avg. Loss: nan

# %%
results_df
# Out:
#      Learning Rate  Batch Size  Hidden Nodes  Hidden Layers       MSE
# 0            0.001          16            32              1  5.035463
# 1            0.001          16            32              2  5.072645
# 2            0.001          16            32              3  5.244679
# 3            0.001          16            32              4  5.373796
# 4            0.001          16            64              1  4.997192
# ..             ...         ...           ...            ...       ...
# 103          0.100          64            64              4       NaN
# 104          0.100          64           128              1       NaN
# 105          0.100          64           128              2       NaN
# 106          0.100          64           128              3       NaN
# 107          0.100          64           128              4       NaN
#
# [108 rows x 5 columns]

# %%
# Find the row with the minimum MSE (best combination of hyperparameters)
min_mse_row = results_df.loc[results_df['MSE'].idxmin()]

# Print the row
print("Row with Minimum MSE:")
print(min_mse_row)
# Out:
# Row with Minimum MSE:
# Learning Rate      0.001000
# Batch Size        64.000000
# Hidden Nodes     128.000000
# Hidden Layers      1.000000
# MSE                4.976275
# Name: 32, dtype: float64

# %% [markdown]
# Increase the number of hidden layers to 10 and use Sigmoid as the activation function in each hidden layer.

# %%
class AbaloneModel_sig(nn.Module):
    def __init__(self, num_hidden_layers=10, num_hidden_nodes=64):
        super(AbaloneModel_sig, self).__init__()
        self.input_layer = nn.Linear(10, num_hidden_nodes)
        self.hidden_layers = nn.ModuleList([nn.Linear(num_hidden_nodes, num_hidden_nodes) for _ in range(num_hidden_layers)])
        self.output_layer = nn.Linear(num_hidden_nodes, 1)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        x = self.sigmoid(self.input_layer(x))
        for layer in self.hidden_layers:
            x = self.sigmoid(layer(x))
        x = self.output_layer(x)
        return x

# Instantiate the model with 10 hidden layers
model_10_layers = AbaloneModel_sig(num_hidden_layers=10)

# Define the loss function and optimizer
criterion = nn.MSELoss()
optimizer = torch.optim.SGD(model_10_layers.parameters(), lr=0.1)

# Training loop
num_epochs = 100
for epoch in range(num_epochs):
    model_10_layers.train()  # Set the model to training mode
    optimizer.zero_grad()  # Clear gradients
    outputs = model_10_layers(X_train_tensor)  # Forward pass
    loss = criterion(outputs, y_train_tensor)  # Calculate loss
    loss.backward()  # Backward pass
    optimizer.step()  # Update weights
    print(f'Epoch [{epoch + 1}/{num_epochs}], Loss: {loss.item():.4f}')

# Evaluate the model on test data
model_10_layers.eval()  # Set the model to evaluation mode
with torch.no_grad():
    outputs_test = model_10_layers(X_test_tensor)
    mse_test = criterion(outputs_test, y_test_tensor)
    print(f'MSE on test data: {mse_test.item():.4f}')
# Out:
# Epoch [1/100], Loss: 101.7770
# Epoch [2/100], Loss: 681.5310
# Epoch [3/100], Loss: 184.7860
# Epoch [4/100], Loss: 121.9349
# Epoch [5/100], Loss: 81.7104
# Epoch [6/100], Loss: 55.9670
# Epoch [7/100], Loss: 39.4913
# Epoch [8/100], Loss: 28.9469
# Epoch [9/100], Loss: 22.1985
# Epoch [10/100], Loss: 17.8796
# Epoch [11/100], Loss: 15.1155
# Epoch [12/100], Loss: 13.3465
# Epoch [13/100], Loss: 12.2143
# Epoch [14/100], Loss: 11.4897
# Epoch [15/100], Loss: 11.0260
# Epoch [16/100], Loss: 10.7292
# Epoch [17/100], Loss: 10.5393
# Epoch [18/100], Loss: 10.4177
# Epoch [19/100], Loss: 10.3399
# Epoch [20/100], Loss: 10.2901
# Epoch [21/100], Loss: 10.2583
# Epoch [22/100], Loss: 10.2379
# Epoch [23/100], Loss: 10.2248
# Epoch [24/100], Loss: 10.2165
# Epoch [25/100], Loss: 10.2111
# Epoch [26/100], Loss: 10.2077
# Epoch [27/100], Loss: 10.2055
# Epoch [28/100], Loss: 10.2041
# Epoch [29/100], Loss: 10.2032
# Epoch [30/100], Loss: 10.2026
# Epoch [31/100], Loss: 10.2023
# Epoch [32/100], Loss: 10.2020
# Epoch [33/100], Loss: 10.2019
# Epoch [34/100], Loss: 10.2018
# Epoch [35/100], Loss: 10.2017
# Epoch [36/100], Loss: 10.2017
# Epoch [37/100], Loss: 10.2016
# Epoch [38/100], Loss: 10.2016
# Epoch [39/100], Loss: 10.2016
# Epoch [40/100], Loss: 10.2016
# Epoch [41/100], Loss: 10.2016
# Epoch [42/100], Loss: 10.2016
# Epoch [43/100], Loss: 10.2016
# Epoch [44/100], Loss: 10.2016
# Epoch [45/100], Loss: 10.2016
# Epoch [46/100], Loss: 10.2016
# Epoch [47/100], Loss: 10.2016
# Epoch [48/100], Loss: 10.2016
# Epoch [49/100], Loss: 10.2016
# Epoch [50/100], Loss: 10.2016
# Epoch [51/100], Loss: 10.2016
# Epoch [52/100], Loss: 10.2016
# Epoch [53/100], Loss: 10.2016
# Epoch [54/100], Loss: 10.2016
# Epoch [55/100], Loss: 10.2016
# Epoch [56/100], Loss: 10.2016
# Epoch [57/100], Loss: 10.2016
# Epoch [58/100], Loss: 10.2016
# Epoch [59/100], Loss: 10.2016
# Epoch [60/100], Loss: 10.2016
# Epoch [61/100], Loss: 10.2016
# Epoch [62/100], Loss: 10.2016
# Epoch [63/100], Loss: 10.2016
# Epoch [64/100], Loss: 10.2016
# Epoch [65/100], Loss: 10.2016
# Epoch [66/100], Loss: 10.2016
# Epoch [67/100], Loss: 10.2016
# Epoch [68/100], Loss: 10.2016
# Epoch [69/100], Loss: 10.2016
# Epoch [70/100], Loss: 10.2016
# Epoch [71/100], Loss: 10.2016
# Epoch [72/100], Loss: 10.2016
# Epoch [73/100], Loss: 10.2016
# Epoch [74/100], Loss: 10.2016
# Epoch [75/100], Loss: 10.2016
# Epoch [76/100], Loss: 10.2016
# Epoch [77/100], Loss: 10.2016
# Epoch [78/100], Loss: 10.2016
# Epoch [79/100], Loss: 10.2016
# Epoch [80/100], Loss: 10.2016
# Epoch [81/100], Loss: 10.2016
# Epoch [82/100], Loss: 10.2016
# Epoch [83/100], Loss: 10.2016
# Epoch [84/100], Loss: 10.2016
# Epoch [85/100], Loss: 10.2016
# Epoch [86/100], Loss: 10.2016
# Epoch [87/100], Loss: 10.2016
# Epoch [88/100], Loss: 10.2016
# Epoch [89/100], Loss: 10.2016
# Epoch [90/100], Loss: 10.2016
# Epoch [91/100], Loss: 10.2016
# Epoch [92/100], Loss: 10.2016
# Epoch [93/100], Loss: 10.2016
# Epoch [94/100], Loss: 10.2016
# Epoch [95/100], Loss: 10.2016
# Epoch [96/100], Loss: 10.2016
# Epoch [97/100], Loss: 10.2016
# Epoch [98/100], Loss: 10.2016
# Epoch [99/100], Loss: 10.2016
# Epoch [100/100], Loss: 10.2016
# MSE on test data: 11.1682

# %% [markdown]
# The output we got shows the loss decreasing steadily over the course of training, which is a positive sign indicating that the model is learning. However, the loss seems to stabilize around a certain value after a few epochs, without further significant improvement.
#
# Observations:
#
# Stable Loss: The loss decreases initially but stabilizes around 10.2016 after several epochs. This stabilization suggests that the model might have reached a plateau in learning and may not further improve beyond this point.
#
# Vanishing Gradient: There doesn't seem to be a significant issue with vanishing gradients in this architecture, as the loss decreases steadily during training. Vanishing gradients usually manifest as very slow or stagnant learning, leading to little or no improvement in the loss over time. However, this does not appear to be the case here, as the loss decreases consistently.
#
# Model Performance Comparison: Comparing this architecture (with 10 or 15 hidden layers using sigmoid activation function with SGD optimizer) to the previous architecture (with 2 hidden layers using ReLU activation), it's essential to consider the final MSE on the test data. In this case, the MSE on the test data is 11.1682, which is higher than the earlier architecture(Relu activation function with SGD optimizer)'s MSE which was approximately 5.46. Therefore, in terms of minimizing the loss (MSE), the previous architecture might be better.
#
# Model Complexity: Increasing the number of hidden layers and using sigmoid activation can make the model more complex. However, complexity doesn't always translate to better performance, as observed in this case. The model might have overfit to the training data or encountered difficulties in learning complex patterns in the data.
#
# In summary, while the model with increased hidden layers and sigmoid activation shows stable learning dynamics, it may not necessarily outperform the previous architecture in terms of minimizing the loss on the test data. It's essential to strike a balance between model complexity and performance, considering factors such as overfitting and computational efficiency. Further experimentation and tuning of hyperparameters may be necessary to improve the model's performance.
